# %% [markdown]
# # 使用tree-sitter用于csharp代码分析

# %%
import os
import pickle
from typing import *

# %% [markdown]
# ## 1. 安装csharp语法扩展
#
# ```bash
# pip install tree-sitter-c-sharp
# ```

# %%
from tree_sitter import Language, Parser

# %%
import tree_sitter_c_sharp

# %%
import tree_sitter

# %%
cslang = tree_sitter.Language(tree_sitter_c_sharp.language())

parser = Parser(cslang)

# 解析 C# 代码
with open("../data/AMC/AlgorithmLib/CScanPicFunction.cs", "rb") as f:
    tree = parser.parse(f.read())

# %%
tree

# %%
def traverse_tree(node, indent=0):
    print(' ' * indent + f'{node.type}')
    for child in node.children:
            traverse_tree(child, indent + 2)

# %%
traverse_tree(tree.root_node)
# Out:
# compilation_unit
#   using_directive
#     using
#     identifier
#     ;
#   using_directive
#     using
#     identifier
#     ;
#   using_directive
#     using
#     identifier
#     ;
#   using_directive
#     using
#     identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       qualified_name
#         identifier
#         .
#         identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       qualified_name
#         identifier
#         .
#         identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     qualified_name
#       qualified_name
#         identifier
#         .
#         identifier
#       .
#       identifier
#     ;
#   using_directive
#     using
#     identifier
#     ;
#   namespace_declaration
#     namespace
#     identifier
#     declaration_list
#       {
#       class_declaration
#         modifier
#           public
#         class
#         identifier
#         declaration_list
#           {
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 array_type
#                   predefined_type
#                   array_rank_specifier
#                     [
#                     ]
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#                 =
#                 real_literal
#               ,
#               parameter
#                 predefined_type
#                 identifier
#                 =
#                 integer_literal
#               )
#             block
#               {
#               comment
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     boolean_literal
#                       false
#                 ;
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ==
#                   null_literal
#                 )
#                 block
#                   {
#                   return_statement
#                     return
#                     integer_literal
#                     ;
#                   }
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     invocation_expression
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                       argument_list
#                         (
#                         argument
#                           binary_expression
#                             identifier
#                             +
#                             identifier
#                         ,
#                         argument
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                         )
#                 ;
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               local_declaration_statement
#                 variable_declaration
#                   generic_name
#                     identifier
#                     type_argument_list
#                       <
#                       predefined_type
#                       >
#                   variable_declarator
#                     identifier
#                     =
#                     object_creation_expression
#                       new
#                       generic_name
#                         identifier
#                         type_argument_list
#                           <
#                           predefined_type
#                           >
#                       argument_list
#                         (
#                         )
#                 ;
#               comment
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ||
#                   binary_expression
#                     identifier
#                     !=
#                     member_access_expression
#                       identifier
#                       .
#                       identifier
#                 )
#                 comment
#                 block
#                   {
#                   comment
#                   for_statement
#                     for
#                     (
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                     binary_expression
#                       identifier
#                       <
#                       identifier
#                     ;
#                     postfix_unary_expression
#                       identifier
#                       ++
#                     )
#                     block
#                       {
#                       local_declaration_statement
#                         variable_declaration
#                           predefined_type
#                           variable_declarator
#                             identifier
#                             =
#                             cast_expression
#                               (
#                               predefined_type
#                               )
#                               invocation_expression
#                                 member_access_expression
#                                   identifier
#                                   .
#                                   identifier
#                                 argument_list
#                                   (
#                                   argument
#                                     cast_expression
#                                       (
#                                       predefined_type
#                                       )
#                                       identifier
#                                   ,
#                                   argument
#                                     element_access_expression
#                                       identifier
#                                       bracketed_argument_list
#                                         [
#                                         argument
#                                           identifier
#                                         ]
#                                   ,
#                                   argument
#                                     identifier
#                                   ,
#                                   argument
#                                     identifier
#                                   ,
#                                   argument
#                                     cast_expression
#                                       (
#                                       predefined_type
#                                       )
#                                       identifier
#                                   ,
#                                   argument
#                                     boolean_literal
#                                       false
#                                   )
#                         ;
#                       expression_statement
#                         invocation_expression
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                           argument_list
#                             (
#                             argument
#                               identifier
#                             )
#                         ;
#                       comment
#                       comment
#                       comment
#                       comment
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           identifier
#                           >=
#                           identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               identifier
#                             ;
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       }
#                   }
#                 else
#                 comment
#                 block
#                   {
#                   for_statement
#                     for
#                     (
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                     binary_expression
#                       identifier
#                       <
#                       identifier
#                     ;
#                     assignment_expression
#                       identifier
#                       +=
#                       integer_literal
#                     )
#                     block
#                       {
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           element_access_expression
#                             identifier
#                             bracketed_argument_list
#                               [
#                               argument
#                                 identifier
#                               ]
#                           <=
#                           identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               identifier
#                             ;
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           binary_expression
#                             parenthesized_expression
#                               (
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                               )
#                             <
#                             identifier
#                           &&
#                           binary_expression
#                             element_access_expression
#                               identifier
#                               bracketed_argument_list
#                                 [
#                                 argument
#                                   binary_expression
#                                     identifier
#                                     +
#                                     integer_literal
#                                 ]
#                             <=
#                             identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                             ;
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           binary_expression
#                             parenthesized_expression
#                               (
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                               )
#                             <
#                             identifier
#                           &&
#                           binary_expression
#                             element_access_expression
#                               identifier
#                               bracketed_argument_list
#                                 [
#                                 argument
#                                   binary_expression
#                                     identifier
#                                     +
#                                     integer_literal
#                                 ]
#                             <=
#                             identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                             ;
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           binary_expression
#                             parenthesized_expression
#                               (
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                               )
#                             <
#                             identifier
#                           &&
#                           binary_expression
#                             element_access_expression
#                               identifier
#                               bracketed_argument_list
#                                 [
#                                 argument
#                                   binary_expression
#                                     identifier
#                                     +
#                                     integer_literal
#                                 ]
#                             <=
#                             identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               binary_expression
#                                 identifier
#                                 +
#                                 integer_literal
#                             ;
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       }
#                   }
#               comment
#               if_statement
#                 if
#                 (
#                 prefix_unary_expression
#                   !
#                   identifier
#                 )
#                 comment
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                   comment
#                   }
#               return_statement
#                 return
#                 identifier
#                 ;
#               }
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 array_type
#                   predefined_type
#                   array_rank_specifier
#                     [
#                     ]
#                 identifier
#               )
#             block
#               {
#               comment
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     boolean_literal
#                       false
#                 ;
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ==
#                   null_literal
#                 )
#                 block
#                   {
#                   return_statement
#                     return
#                     integer_literal
#                     ;
#                   }
#               if_statement
#                 if
#                 (
#                 identifier
#                 )
#                 comment
#                 block
#                   {
#                   for_statement
#                     for
#                     (
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                     binary_expression
#                       identifier
#                       <
#                       invocation_expression
#                         member_access_expression
#                           identifier
#                           .
#                           identifier
#                         argument_list
#                           (
#                           argument
#                             binary_expression
#                               identifier
#                               +
#                               identifier
#                           ,
#                           argument
#                             member_access_expression
#                               identifier
#                               .
#                               identifier
#                           )
#                     ;
#                     postfix_unary_expression
#                       identifier
#                       ++
#                     )
#                     block
#                       {
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           element_access_expression
#                             identifier
#                             bracketed_argument_list
#                               [
#                               argument
#                                 identifier
#                               ]
#                           >=
#                           identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       }
#                   }
#                 else
#                 comment
#                 block
#                   {
#                   for_statement
#                     for
#                     (
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                     binary_expression
#                       identifier
#                       <
#                       invocation_expression
#                         member_access_expression
#                           identifier
#                           .
#                           identifier
#                         argument_list
#                           (
#                           argument
#                             binary_expression
#                               identifier
#                               +
#                               identifier
#                           ,
#                           argument
#                             member_access_expression
#                               identifier
#                               .
#                               identifier
#                           )
#                     ;
#                     postfix_unary_expression
#                       identifier
#                       ++
#                     )
#                     block
#                       {
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           element_access_expression
#                             identifier
#                             bracketed_argument_list
#                               [
#                               argument
#                                 identifier
#                               ]
#                           <=
#                           identifier
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               boolean_literal
#                                 true
#                             ;
#                           break_statement
#                             break
#                             ;
#                           }
#                       }
#                   }
#               if_statement
#                 if
#                 (
#                 prefix_unary_expression
#                   !
#                   identifier
#                 )
#                 comment
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       identifier
#                     ;
#                   comment
#                   }
#               return_statement
#                 return
#                 binary_expression
#                   identifier
#                   -
#                   identifier
#                 ;
#               }
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 array_type
#                   predefined_type
#                   array_rank_specifier
#                     [
#                     ]
#                 identifier
#               )
#             block
#               {
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     member_access_expression
#                       identifier
#                       .
#                       identifier
#                 ;
#               comment
#               for_statement
#                 for
#                 (
#                 ;
#                 binary_expression
#                   identifier
#                   <
#                   member_access_expression
#                     identifier
#                     .
#                     identifier
#                 ;
#                 postfix_unary_expression
#                   identifier
#                   ++
#                 )
#                 block
#                   {
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       element_access_expression
#                         identifier
#                         bracketed_argument_list
#                           [
#                           argument
#                             identifier
#                           ]
#                       >=
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                     )
#                     block
#                       {
#                       break_statement
#                         break
#                         ;
#                       }
#                   }
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               comment
#               return_statement
#                 return
#                 binary_expression
#                   binary_expression
#                     parenthesized_expression
#                       (
#                       binary_expression
#                         binary_expression
#                           binary_expression
#                             invocation_expression
#                               member_access_expression
#                                 identifier
#                                 .
#                                 identifier
#                               argument_list
#                                 (
#                                 argument
#                                   identifier
#                                 )
#                             *
#                             identifier
#                           /
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                         +
#                         identifier
#                       )
#                     *
#                     identifier
#                   /
#                   integer_literal
#                 ;
#               }
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             identifier
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#                 =
#                 boolean_literal
#                   true
#               )
#             block
#               {
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               if_statement
#                 if
#                 (
#                 prefix_unary_expression
#                   !
#                   identifier
#                 )
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       invocation_expression
#                         identifier
#                         argument_list
#                           (
#                           argument
#                             identifier
#                           ,
#                           argument
#                             identifier
#                           )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       cast_expression
#                         (
#                         predefined_type
#                         )
#                         identifier
#                     ;
#                   }
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ==
#                   member_access_expression
#                     identifier
#                     .
#                     identifier
#                 )
#                 block
#                   {
#                   return_statement
#                     return
#                     invocation_expression
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                       argument_list
#                         (
#                         argument
#                           identifier
#                         ,
#                         argument
#                           identifier
#                         ,
#                         argument
#                           identifier
#                         )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       *=
#                       integer_literal
#                     ;
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       identifier
#                       <
#                       integer_literal
#                     )
#                     block
#                       {
#                       expression_statement
#                         assignment_expression
#                           identifier
#                           =
#                           integer_literal
#                         ;
#                       }
#                     else
#                     block
#                       {
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           identifier
#                           <
#                           integer_literal
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               integer_literal
#                             ;
#                           }
#                       if_statement
#                         if
#                         (
#                         binary_expression
#                           identifier
#                           >
#                           integer_literal
#                         )
#                         block
#                           {
#                           expression_statement
#                             assignment_expression
#                               identifier
#                               =
#                               integer_literal
#                             ;
#                           }
#                       }
#                   comment
#                   local_declaration_statement
#                     variable_declaration
#                       identifier
#                       variable_declarator
#                         identifier
#                         =
#                         invocation_expression
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                           argument_list
#                             (
#                             argument
#                               element_access_expression
#                                 member_access_expression
#                                   member_access_expression
#                                     identifier
#                                     .
#                                     identifier
#                                   .
#                                   identifier
#                                 bracketed_argument_list
#                                   [
#                                   argument
#                                     identifier
#                                   ]
#                             )
#                     ;
#                   return_statement
#                     return
#                     identifier
#                     ;
#                   }
#               }
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 array_type
#                   predefined_type
#                   array_rank_specifier
#                     [
#                     ]
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#                 =
#                 boolean_literal
#                   true
#               )
#             block
#               {
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               if_statement
#                 if
#                 (
#                 prefix_unary_expression
#                   !
#                   identifier
#                 )
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       invocation_expression
#                         identifier
#                         argument_list
#                           (
#                           argument
#                             identifier
#                           ,
#                           argument
#                             identifier
#                           )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       cast_expression
#                         (
#                         predefined_type
#                         )
#                         identifier
#                     ;
#                   }
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ==
#                   member_access_expression
#                     identifier
#                     .
#                     identifier
#                 )
#                 block
#                   {
#                   return_statement
#                     return
#                     invocation_expression
#                       member_access_expression
#                         invocation_expression
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                           argument_list
#                             (
#                             argument
#                               identifier
#                             ,
#                             argument
#                               identifier
#                             ,
#                             argument
#                               identifier
#                             )
#                         .
#                         identifier
#                       argument_list
#                         (
#                         )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       *=
#                       integer_literal
#                     ;
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       identifier
#                       <
#                       integer_literal
#                     )
#                     block
#                       {
#                       expression_statement
#                         assignment_expression
#                           identifier
#                           =
#                           integer_literal
#                         ;
#                       }
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       identifier
#                       >
#                       integer_literal
#                     )
#                     block
#                       {
#                       expression_statement
#                         assignment_expression
#                           identifier
#                           =
#                           integer_literal
#                         ;
#                       }
#                   comment
#                   local_declaration_statement
#                     variable_declaration
#                       predefined_type
#                       variable_declarator
#                         identifier
#                         =
#                         element_access_expression
#                           identifier
#                           bracketed_argument_list
#                             [
#                             argument
#                               identifier
#                             ]
#                     ;
#                   return_statement
#                     return
#                     identifier
#                     ;
#                   }
#               }
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#                 =
#                 boolean_literal
#                   true
#               )
#             block
#               {
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     integer_literal
#                 ;
#               if_statement
#                 if
#                 (
#                 prefix_unary_expression
#                   !
#                   identifier
#                 )
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       invocation_expression
#                         identifier
#                         argument_list
#                           (
#                           argument
#                             identifier
#                           ,
#                           argument
#                             identifier
#                           )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       cast_expression
#                         (
#                         predefined_type
#                         )
#                         identifier
#                     ;
#                   }
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   ==
#                   member_access_expression
#                     identifier
#                     .
#                     identifier
#                 )
#                 block
#                   {
#                   return_statement
#                     return
#                     invocation_expression
#                       member_access_expression
#                         invocation_expression
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                           argument_list
#                             (
#                             argument
#                               identifier
#                             ,
#                             argument
#                               identifier
#                             ,
#                             argument
#                               identifier
#                             )
#                         .
#                         identifier
#                       argument_list
#                         (
#                         )
#                     ;
#                   }
#                 else
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       *=
#                       integer_literal
#                     ;
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       identifier
# ...
#                                   )
#                                   block
#                                     {
#                                     expression_statement
#                                       assignment_expression
#                                         element_access_expression
#                                           identifier
#                                           bracketed_argument_list
#                                             [
#                                             argument
#                                               identifier
#                                             ]
#                                         =
#                                         binary_expression
#                                           binary_expression
#                                             element_access_expression
#                                               element_access_expression
#                                                 identifier
#                                                 bracketed_argument_list
#                                                   [
#                                                   argument
#                                                     identifier
#                                                   ]
#                                               bracketed_argument_list
#                                                 [
#                                                 argument
#                                                   identifier
#                                                 ,
#                                                 argument
#                                                   integer_literal
#                                                 ]
#                                             /
#                                             integer_literal
#                                           *
#                                           identifier
#                                       ;
#                                     }
#                                   else
#                                   block
#                                     {
#                                     expression_statement
#                                       assignment_expression
#                                         element_access_expression
#                                           identifier
#                                           bracketed_argument_list
#                                             [
#                                             argument
#                                               identifier
#                                             ]
#                                         =
#                                         binary_expression
#                                           binary_expression
#                                             prefix_unary_expression
#                                               -
#                                               element_access_expression
#                                                 element_access_expression
#                                                   identifier
#                                                   bracketed_argument_list
#                                                     [
#                                                     argument
#                                                       identifier
#                                                     ]
#                                                 bracketed_argument_list
#                                                   [
#                                                   argument
#                                                     identifier
#                                                   ,
#                                                   argument
#                                                     integer_literal
#                                                   ]
#                                             /
#                                             integer_literal
#                                           *
#                                           identifier
#                                       ;
#                                     }
#                                 }
#                       comment
#                       comment
#                       expression_statement
#                         invocation_expression
#                           member_access_expression
#                             identifier
#                             .
#                             identifier
#                           argument_list
#                             (
#                             argument
#                               identifier
#                             ,
#                             argument
#                               identifier
#                             ,
#                             argument
#                               invocation_expression
#                                 identifier
#                                 argument_list
#                                   (
#                                   argument
#                                     element_access_expression
#                                       identifier
#                                       bracketed_argument_list
#                                         [
#                                         argument
#                                           identifier
#                                         ]
#                                   ,
#                                   argument
#                                     identifier
#                                   ,
#                                   argument
#                                     identifier
#                                   ,
#                                   argument
#                                     identifier
#                                   )
#                             )
#                         ;
#                       }
#                   }
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   !=
#                   null_literal
#                 )
#                 block
#                   {
#                   expression_statement
#                     invocation_expression
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                       argument_list
#                         (
#                         )
#                     ;
#                   }
#               expression_statement
#                 assignment_expression
#                   identifier
#                   =
#                   object_creation_expression
#                     new
#                     identifier
#                     argument_list
#                       (
#                       argument
#                         identifier
#                       ,
#                       argument
#                         member_access_expression
#                           identifier
#                           .
#                           identifier
#                       ,
#                       argument
#                         member_access_expression
#                           identifier
#                           .
#                           identifier
#                       )
#                 ;
#               return_statement
#                 return
#                 identifier
#                 ;
#               }
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 identifier
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               )
#             block
#               {
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   >
#                   identifier
#                 )
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       binary_expression
#                         identifier
#                         /
#                         integer_literal
#                     ;
#                   }
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     cast_expression
#                       (
#                       predefined_type
#                       )
#                       parenthesized_expression
#                         (
#                         binary_expression
#                           binary_expression
#                             identifier
#                             *
#                             identifier
#                           /
#                           identifier
#                         )
#                 ;
#               comment
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     member_access_expression
#                       identifier
#                       .
#                       identifier
#                 ;
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   binary_expression
#                     identifier
#                     +
#                     binary_expression
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                       *
#                       identifier
#                   <
#                   integer_literal
#                 )
#                 block
#                   {
#                   comment
#                   comment
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       binary_expression
#                         prefix_unary_expression
#                           -
#                           identifier
#                         -
#                         identifier
#                     ;
#                   if_statement
#                     if
#                     (
#                     binary_expression
#                       prefix_unary_expression
#                         -
#                         integer_literal
#                       ==
#                       member_access_expression
#                         identifier
#                         .
#                         identifier
#                     )
#                     comment
#                     block
#                       {
#                       expression_statement
#                         assignment_expression
#                           identifier
#                           =
#                           integer_literal
#                         ;
#                       }
#                     else
#                     block
#                       {
#                       expression_statement
#                         assignment_expression
#                           identifier
#                           =
#                           identifier
#                         ;
#                       comment
#                       }
#                   }
#               return_statement
#                 return
#                 identifier
#                 ;
#               }
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           comment
#           method_declaration
#             modifier
#               public
#             modifier
#               static
#             predefined_type
#             identifier
#             parameter_list
#               (
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               ,
#               parameter
#                 predefined_type
#                 identifier
#               )
#             block
#               {
#               comment
#               local_declaration_statement
#                 variable_declaration
#                   predefined_type
#                   variable_declarator
#                     identifier
#                     =
#                     cast_expression
#                       (
#                       predefined_type
#                       )
#                       parenthesized_expression
#                         (
#                         binary_expression
#                           cast_expression
#                             (
#                             identifier
#                             )
#                             prefix_unary_expression
#                               *
#                               identifier
#                           /
#                           identifier
#                         )
#                 ;
#               comment
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   parenthesized_expression
#                     (
#                     binary_expression
#                       binary_expression
#                         binary_expression
#                           identifier
#                           +
#                           identifier
#                         +
#                         identifier
#                       +
#                       identifier
#                     )
#                   >
#                   identifier
#                 )
#                 block
#                   {
#                   comment
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       binary_expression
#                         binary_expression
#                           binary_expression
#                             identifier
#                             -
#                             identifier
#                           -
#                           identifier
#                         -
#                         identifier
#                     ;
#                   }
#               comment
#               if_statement
#                 if
#                 (
#                 binary_expression
#                   identifier
#                   <
#                   integer_literal
#                 )
#                 block
#                   {
#                   expression_statement
#                     assignment_expression
#                       identifier
#                       =
#                       binary_expression
#                         identifier
#                         -
#                         identifier
#                     ;
#                   }
#               return_statement
#                 return
#                 identifier
#                 ;
#               }
#           }
#       }

# %% [markdown]
# ## 2. 解析csharp项目结构
#
# 1. 引用声明，区分外部库以及本地项目文件引用
# 2. 注释，包括代码文件注释以及类的docstring
# 3. 类以及类的成员，构建两个层级的对象`class-->attribute`之后分析以attribute为基本粒度，得到结果之后与类注释一起作为类功能分析的输入
# 4. 根据引用声明构建项目文件之间的依赖关系，建立图结构

# %% [markdown]
# ### 2.1 抽取引用信息

# %%
# 提取引用库信息
def extract_qualified_name(node):
    parts = []
    if node.type == 'qualified_name':
        for child in node.children:
            if child.type == 'identifier':
                parts.append(child.text.decode('utf-8'))
            elif child.type == 'qualified_name':
                parts.extend(extract_qualified_name(child))
    return parts
    
# 提取引用库信息
def extract_using_directives(node):
    using_directives = []
    if f'{node.type}' == 'using_directive':
        for child in node.children:
            if f'{child.type}' == 'qualified_name':
                parts = extract_qualified_name(child)
                using_directives.append('.'.join(parts))
    for child in node.children:
        using_directives.extend(extract_using_directives(child))
    return using_directives

# %%
# 从根节点开始提取
using_directives = extract_using_directives(tree.root_node)

# 输出引用库的完整名称
for library in using_directives:
    print(library)
# Out:
# System.Collections.Generic
# System.Diagnostics
# System.Drawing
# System.IO
# System.Linq
# System.Text
# System.Threading
# System.Threading.Tasks
# System.Windows.Forms

# %% [markdown]
# ### 2.2 抽取代码文件注释

# %%
def extract_file_level_comments(node, is_file_level=True):
    comments = []
    if node.type == 'comment' and is_file_level:
        comments.append(node.text.decode('utf-8'))
    elif node.type in ['class_declaration', 'method_declaration']:
        is_file_level = False
    for child in node.children:
        comments.extend(extract_file_level_comments(child, is_file_level))
    return comments

# 从根节点开始提取
file_level_comments = extract_file_level_comments(tree.root_node)

# %%
file_level_comments
# Out:
# []

# %% [markdown]
# ### 2.3 解析类
#
# 类，类注释，方法，方法注释

# %%
# 提取类、类注释、方法名、方法注释、方法的全部代码块文本以及类的所有代码文本
def extract_method_info(node):
    method_info = []
    if node.type == 'method_declaration':
        method_dict = {
            'method_name': '',
            'method_comment': '',
            'method_code': '',
            'method_prefix': '',
            'method_param': ''
        }
        method_prefix = []
        method_param = []
        method_code = []
        decode_type = 'utf-8'
        for child in node.children:
            if child.type == 'identifier':
                method_dict['method_name'] = child.text.decode(decode_type, errors="ignore")
            elif child.type == 'comment':
                method_dict['method_comment'] = child.text.decode(decode_type, errors="ignore")
            elif child.type == 'modifier':
                method_prefix.append(child.text.decode(decode_type, errors="ignore"))
            elif child.type == 'parameter_list':
                method_param.append(child.text.decode(decode_type, errors="ignore"))
            method_code.append(child.text.decode(decode_type, errors="ignore"))
        method_dict['method_prefix'] = ' '.join(method_prefix)
        method_dict['method_param'] = ' '.join(method_param)
        method_dict['method_code'] = ''.join(method_code)
        method_info.append(method_dict)
    for child in node.children:
        method_info.extend(extract_method_info(child))
    return method_info
    
def extract_class_info(node):
    class_info = []
    if node.type == 'class_declaration':
        class_dict = {
            'class_name': '',
            'class_comment': '',
            'class_code': '',
            'methods': []
        }
        decode_type = 'utf-8'
        for child in node.children:
            if child.type == 'identifier':
                class_dict['class_name'] = child.text.decode(decode_type, errors="ignore")
            elif child.type == 'comment':
                class_dict['class_comment'] = child.text.decode(decode_type, errors="ignore")
            elif child.type == 'declaration_list':
                class_dict['methods'] = extract_method_info(child)
                class_dict['class_code'] = child.text.decode(decode_type, errors="ignore")
        class_info.append(class_dict)
    for child in node.children:
        class_info.extend(extract_class_info(child))
    return class_info

# 从根节点开始提取
class_info = extract_class_info(tree.root_node)

# %%
class_info
# Out:
# [{'class_name': 'CScanPicFunction',
#   'class_comment': '',
#   'class_code': '{\r\n\r\n\r\n        /// <summary>\r\n        ///  在闸门内查找第一个与波形的交叉点\r\n        /// </summary>\r\n        /// <param name="threshValue">阈值(转换为0-2^N,N是卡的位数,譬如8位卡,就是256)</param>\r\n        /// <param name="gateLengthNum">闸门长度</param>\r\n        /// <param name="gateStartNum">闸门在A信号中的起始位置</param>\r\n        /// <param name="isPositiveThresh">计算正向阈值标志,true：正向;false:负向</param>\r\n        /// <param name="ascandata">A信号数据</param>\r\n        /// <returns></returns>\r\n        public static int FindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)\r\n        {\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos += 4 ...
#   'methods': [{'method_name': 'FindFirstPostionInFSFGate',
#     'method_comment': '',
#     'method_code': 'publicstaticintFindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                    if ((iPos + 1) < iposMax && ascandata[iPos + 1] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos + 1;\r\n                        bHasFound = true;\r\n     ...
#     'method_prefix': 'public static',
#     'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)'},
#    {'method_name': 'FindFirstPostionRelativeInGate',
#     'method_comment': '',
#     'method_code': 'publicstaticintFindFirstPostionRelativeInGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n\r\n\r\n            if (isPositiveThresh)//正向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] >= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n\r\n            if (!bHasFound) //如果没找到符合条件的值，则返回FSF闸门0 \r\n            {\r\n                iPos = gateStartNum;//相对于起点，这是绝对位置\r\n            }\r\n            return iPos - gateStartNum;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata)'},
#    {'method_name': 'CalCouplantDepth',
#     'method_comment': '',
#     'method_code': 'publicstaticdoubleCalCouplantDepth(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata){\r\n            int indexStartWave = FSFGate.m_GateStartNum;\r\n            //int indexSufaceWave = FSFGate.m_GateStartNum;\r\n            for (; indexStartWave < ascandata.Length; indexStartWave++)\r\n            {\r\n                if (ascandata[indexStartWave] >= FSFGate.ThreshAMP)\r\n                {\r\n                    break;\r\n                }\r\n            }\r\n            //for (; indexSufaceWave < Math.Min(FSFGate.m_GateStartNum + FSFGate.m_GateLengthNum, ascandata.Length); indexSufaceWave++)\r\n            //{\r\n            //    if (ascandata[indexSufaceWave] >= FSFGate.ThreshAMP)\r\n            //    {\r\n            //        break;\r\n            //    }\r\n\r\n            //}\r\n            return (Math.Abs(indexStartWave) * timeLen / ascandata.Length + timedelay) * v / 2;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata)'},
#    {'method_name': 'DataToColor',
#     'method_comment': '',
#     'method_code': 'publicstaticColorDataToColor(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res);\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                else\r\n                {\r\n                    if (res < 1)\r\n                    {\r\n                        res = 1;\r\n                    }\r\n                    if (res > 511)\r\n                    {\r\n                        res = 511;\r\n                    }\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                Color colorRet = Color.FromArgb(colorBar.m_CColorData.m_ColorTab[res]);\r\n                return colorRet;\r\n            }\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#    {'method_name': 'DataToColorForInt',
#     'method_comment': '',
#     'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true)'},
#    {'method_name': 'DataToColorForInt',
#     'method_comment': '',
#     'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = colorBar.m_CColorData.m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#    {'method_name': 'OutOldColorBar',
#     'method_comment': '',
#     'method_code': 'publicstaticvoidOutOldColorBar(){\r\n            double step = 0.25 / 63.75;\r\n            int R = 0, G = 0, B = 0;\r\n            double VoltageScope = 1.0;\r\n            for (double data = 0; data <= 1; data += step)\r\n            {\r\n\r\n                if (data <= 0)\r\n                    R = G = B = 0;\r\n                else if (data <= VoltageScope / 4)\r\n                {\r\n                    R = G = 0;\r\n                    B = Functions.RoundToInt(data * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope / 2)\r\n                {\r\n                    R = 0;\r\n                    G = Functions.RoundToInt((data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                    B = Functions.RoundToInt(255 - (data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope * 3 / 4)\r\n                {\r\n                    R = Functions.RoundToInt((data - VoltageScope / 2) * 255 * 4 / VoltageScope);\r\n                    G = 255;\r\n                    B = 0;\r\n                }\r\n\r\n                else if (data <= VoltageScope)\r\n                {\r\n                    R = 255;\r\n                    G = Functions.RoundToInt(255 - (data - VoltageScope * 3 / 4) * 255 * 4 / VoltageScope);\r\n                    B = 0;\r\n                }\r\n\r\n                else\r\n                {\r\n                    R = 255;\r\n                    G = 0;\r\n                    B = 0;\r\n                }\r\n            }\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '()'},
#    {'method_name': 'AdjustPeakData',
#     'method_comment': '',
#     'method_code': 'publicstaticdouble[]AdjustPeakData(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd){\r\n            int iLen = scanNum * indexNum;\r\n            double[] result = new double[iLen];\r\n            double min, max;\r\n            min = double.MaxValue;\r\n            max = double.MinValue;\r\n\r\n            for (int i = 0; i < iLen; i++) //先找到最大、最小值\r\n            {\r\n                if (data[i] > max)\r\n                {\r\n                    max = data[i];\r\n                }\r\n                if (data[i] < min)\r\n                {\r\n                    min = data[i];\r\n                }\r\n            }\r\n\r\n\r\n            double valZone = max - min;\r\n            for (int i = 0; i < iLen; i++)\r\n            {\r\n                result[i] = NumConversionTo256((data[i] - min) * m_MaxVoltage / valZone, wd);\r\n            }\r\n            return result;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd)'},
#    {'method_name': 'CheckFileFormat',
#     'method_comment': '',
#     'method_code': 'publicstaticboolCheckFileFormat(Config config, int ishowChanNo){\r\n            if (config.m_DataGateList.Count <= 0 || config.m_DataGateList.Count > 10)//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n            for (int i = 0; i < config.m_DataGateList.Count; i++)\r\n            {\r\n                if (config.m_DataGateList[i].m_GateLength <= 0.01 || config.m_DataGateList[i].m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_Threshold < 0 || config.m_DataGateList[i].m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_FSFGate.m_GateIsActived)\r\n            {\r\n                if (config.m_FSFGate.m_GateLength <= 0.01 || config.m_FSFGate.m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_Threshold < 0 || config.m_FSFGate.m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_ScanNum <= 0\r\n                   || config.m_ScanNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   )//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n\r\n            if (ishowChanNo != 0)\r\n            {\r\n                return false;\r\n            }\r\n\r\n\r\n            //if (StaticParas.glConfig.m_AscanLength <= 0 )//数据格式不对\r\n            //{\r\n            //    return false;\r\n            //}\r\n\r\n            return true;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(Config config, int ishowChanNo)'},
#    {'method_name': 'ReadNewVersionData',
#     'method_comment': '',
#     'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata){\r\n            try\r\n            {\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n\r\n\r\n\r\n\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString();\r\n                string[] arrcomment = strcomment.Split(\',\');\r\n                for (i ...
#     'method_prefix': 'public static',
#     'method_param': '(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata)'},
#    {'method_name': 'ReadNewVersionData',
#     'method_comment': '',
#     'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk){\r\n            try\r\n            {\r\n                isReadOk = false;\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString(); ...
#     'method_prefix': 'public static',
#     'method_param': '(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk)'},
#    {'method_name': 'GetAbsPeakValueInGate',
#     'method_comment': '',
#     'method_code': 'publicstaticdoubleGetAbsPeakValueInGate(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP){\r\n            double temp, tempMax, tempMin;\r\n            temp = 0;\r\n            tempMax = 0;\r\n            tempMin = 0;\r\n            double thresholdFSF = FSFGate.m_Threshold;\r\n            int gateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int gateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n\r\n            // (X,Y)转换成一维\r\n\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = 0;\r\n            if ((curFSFFirstPosition + gateStartNum + gateLengthNum) > currAScanData.Length)\r\n            {\r\n                lengthNum = currAScanData.Length;\r\n            }\r\n            else\r\n            {\r\n                lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            }\r\n\r\n            for (int k = curFSFFirstPosition + gateStartNum; k < lengthNum; k++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = k;\r\n                if (currAScanData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    //temp = ((double)allData[indexOfAscan, indexOfBScan, k] - 256) * maxVoltage / 128;\r\n                    temp = ((double)currAScanData[currndex] - maxAMP) * maxVoltage / (maxAMP / 2);\r\n                    if (temp < tempMin && temp < -thresholdData)\r\n                    {\r\n                        tempMin = temp;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)currAScanData[currndex] * maxVoltage / (maxAMP / 2);\r\n                    if (temp > tempMax && temp > thresholdData)\r\n                    {\r\n                        tempMax = temp;\r\n                    }\r\n                }\r\n            }\r\n            double absMin = Math.Abs(tempMin);\r\n            if (absMin > tempMax)\r\n            {\r\n                return absMin;\r\n            }\r\n            else\r\n            {\r\n                return tempMax;\r\n            }\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP)'},
#    {'method_name': 'FindValueInGate',
#     'method_comment': '',
#     'method_code': 'publicstaticintFindValueInGate(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound){\r\n            int iTOF;\r\n            bHasFound = false;\r\n            double temp = 0;\r\n\r\n            if ((curFSFFirstPosition + gateStartNum) < 0) //确保数据闸门的实际起始位置在窗口中\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum) > allData.GetLength(0) ? allData.GetLength(0) : (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            for (iTOF = curFSFFirstPosition + gateStartNum; iTOF < lengthNum; iTOF++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = iTOF;\r\n                if (allData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    temp = (8191 - (double)allData[currndex]) * maxVoltage / (maxAMP / 2);\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)allData[currndex] * maxVoltage / (maxAMP / 2);\r\n                }\r\n                if (value < 0)\r\n                {\r\n                    if (temp <= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    if (temp >= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            if (bHasFound == false)\r\n            {\r\n                iTOF = lengthNum - 1; //如果没找到符合条件的值，则返回最大时间点的下标            \r\n            }\r\n            return iTOF;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound)'},
#    {'method_name': 'CalculateFFT',
#     'method_comment': '',
#     'method_code': 'publicstaticdouble[]CalculateFFT(double[] AscanData){\r\n            //s1:求A信号中的平均值\r\n            double Avg = 0;\r\n            int AscanPoints = AscanData.Length;\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                Avg += AscanData[k];\r\n            }\r\n            Avg = Avg / AscanPoints;\r\n            //s2:去直流分量\r\n            double[] data_ascan = new double[AscanPoints];\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                data_ascan[k] = AscanData[k] - Avg;\r\n                if (data_ascan[k] > StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1)\r\n                {\r\n                    data_ascan[k] = StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1;\r\n                }\r\n                if (data_ascan[k] < -StaticParas.glRDDataCard.MAX_AMP_V / 2)\r\n                {\r\n                    data_ascan[k] = -StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n                }\r\n\r\n                data_ascan[k] /= StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n            }\r\n\r\n            double[] image = new double[data_ascan.Length];\r\n            double[] spectrum = new double[data_ascan.Length];\r\n\r\n            MathNet.Numerics.IntegralTransforms.Fourier.Forward(data_ascan, image);\r\n            int index = 0;\r\n            foreach (double re in data_ascan)\r\n            {\r\n                double im = image[index];\r\n                spectrum[index] = Math.Sqrt(re * re + im * im);\r\n                index++;\r\n            }\r\n\r\n\r\n\r\n            //  FftAlgorithm.Calculate(data_ascan); //进行FFT转换\r\n\r\n\r\n            //MaxSpectrum = spectrum.Max(); //最大频谱值\r\n            //MinSpectrum = spectrum.Min(); //最小频谱值\r\n\r\n            return spectrum;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double[] AscanData)'},
#    {'method_name': 'CalclatMeanOfAScan',
#     'method_comment': '',
#     'method_code': 'publicstaticdoubleCalclatMeanOfAScan(int iStart, int lengthNum, byte[] AScanData){\r\n            long v = 0;\r\n            int actualLen = Math.Min(iStart + lengthNum, AScanData.Length);\r\n            for (int i = iStart; i < actualLen; i++)\r\n            {\r\n                v += AScanData[i];\r\n            }\r\n            return (v * 1.0 / actualLen);\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(int iStart, int lengthNum, byte[] AScanData)'},
#    {'method_name': 'DrawMeanValueImage',
#     'method_comment': '',
#     'method_code': 'publicstaticvoidDrawMeanValueImage(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           ){\r\n\r\n               \r\n            //, int totalChannum\r\n            //, int averageValue\r\n            //, WaveDataStyle wd\r\n            //)\r\n\r\n            int m_GateLengthNum = dataGate.m_GateLengthNum;\r\n            int m_GateStartNum = dataGate.m_GateStartNum;\r\n            double m_ThresholdFSF = FSFGate.m_Threshold;\r\n            int m_GateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int m_GateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n            double m_ThresholdData = dataGate.m_Threshold;\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //for (int k = 0; k < m_IndexNum* m_ScanNum; k++)\r\n            //  int k = 0;\r\n\r\n            // Stopwatch sw = new Stopwatch();\r\n            //  sw.Start();\r\n            // System.Threading.Tasks.Parallel.ForEach(ascanData, (adata, state1) =>\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //foreach (byte[] adata in ascanData)\r\n            {\r\n                byte[] adata = ascanData[k];\r\n                //for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int i = k % m_ScanNum;\r\n                    int j = k / m_ScanNum;\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n\r\n                    if (indexofAScan > ascanData.Count - 1 || adata.Length <= 0)\r\n                    {\r\n                        m_PeakData[indexofAScan] = 0;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n                        // 取得同步闸门起点\r\n                        int curFSFFirstPosition = 0;\r\n                        if (FSFGate.m_GateIsActived)\r\n                        {\r\n                            curFSFFirstPosition = CScanPicFunction.FindFirstPostionInFSFGate(\r\n                                  FSFGate.ThreshAMP //阈值对应的正向幅值\r\n                                , FSFGate.m_GateLengthNum//同步闸门的长度\r\n                                , FSFGate.m_GateStartNum//同步闸门的开始位置,信号的下标\r\n                                , FSFGate.isPositiveThresh//正向阈值\r\n                                , adata\r\n                                , wd\r\n                                , offset\r\n                                , maxAMP\r\n                                );\r\n                        }\r\n                        //确保数据闸门的实际起始位置在窗口中\r\n                        if ((curFSFFirstPosition + m_GateStartNum) < 0)\r\n                        {\r\n                            m_GateStartNum = -curFSFFirstPosition;\r\n                        }\r\n                        int lengthNum = 0;\r\n                        if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum) > ascanData[indexofAScan].GetLength(0))\r\n                        {\r\n                            lengthNum = ascanData[indexofAScan].GetLength(0);\r\n                        }\r\n                        else\r\n                        {\r\n                            lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum;\r\n                        }\r\n                        //底波和表面波计算数据闸门的起点\r\n                        int iStart = m_GateStartNum;//只有数据闸门\r\n                        if (FSFGate.m_GateIsActived)//有同步闸门\r\n                        {\r\n          ...
#     'method_prefix': 'public static',
#     'method_param': '(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           )'},
#    {'method_name': 'DrawFreqDomainImage',
#     'method_comment': '',
#     'method_code': 'publicstaticvoidDrawFreqDomainImage(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            ){\r\n\r\n\r\n            int startIndex = 0;\r\n            int endIndex = 0;\r\n\r\n            int AscanPoints = 0;\r\n            int AScanDataLen = ascanData[0].Length;\r\n\r\n            AscanPoints = dataGate.m_GateLengthNum; //需要计算的部分\r\n            startIndex = FSFGate.m_CurFSFFirstPosition + FSFGate.m_iUseBottomWave * dataGate.m_GateStartNum;\r\n            startIndex = startIndex < 0 ? 0 : startIndex;//确保数据闸门的实际起始位置在窗口中\r\n\r\n            endIndex = (startIndex//数据闸门起始位置\r\n                        + dataGate.m_GateLengthNum);//数据闸门的长度\r\n\r\n            endIndex = (endIndex) > AScanDataLen ? AScanDataLen : (endIndex);//结束下标\r\n\r\n            int dataLength = Functions.NextPower2(AscanPoints);//计算FFT的数据长度\r\n            dataLength = (int)Math.Pow(2, dataLength);//2^N\r\n            //dataLength = AscanPoints;//\r\n            int drawindex = (int)(computeFreq / displayFreq * dataLength);//获取的频幅值所在的位置\r\n            drawindex = drawindex > dataLength - 1 ? dataLength - 1 : drawindex;\r\n\r\n            double[] drawFreqAmp = new double[m_IndexNum * m_ScanNum];\r\n\r\n            double MaxAmp = double.MinValue;\r\n            double MinAmp = double.MaxValue;\r\n\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //{\r\n            //    for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n                    byte[] adata = ascanData[k];\r\n\r\n                    //int indexofAScan = j * m_ScanNum + i;\r\n                    byte[] AScanData = ascanData[indexofAScan];\r\n                    if (AScanData.Length <= 0 || AScanData.Length < AScanDataLen)\r\n                    {\r\n                        drawFreqAmp[indexofAScan] = 0;\r\n                        //return;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n\r\n\r\n                        double[] data = new double[dataLength]; //存放门限中的数据\r\n                        for (int m = startIndex; m < endIndex; m++)\r\n                        {\r\n\r\n                            data[m - startIndex] = (double)AScanData[m];\r\n                        }\r\n                        double[] spectrum = CalculateFFT(data);\r\n                        double tmpMax = spectrum.Max();\r\n                        double tmpMin = spectrum.Min();\r\n                        MaxAmp = MaxAmp < tmpMax ? tmpMax : MaxAmp;\r\n                        MinAmp = MinAmp > tmpMin ? tmpMin : MinAmp;\r\n\r\n                        drawFreqAmp[indexofAScan] = spectrum[drawindex];\r\n                    }\r\n                    //m_PeakDataInt[indexOfAScan] = (int)(drawFreqAmp[indexOfAScan] / (tmpMax - tmpMin) * (maxAMP - 1));\r\n                });\r\n            //将数据转换0-255之间的数\r\n            for (int k = 0; k < drawFreqAmp.Length; k++)\r\n            {\r\n                m_PeakData[k] = ((drawFreqAmp[k] - MinAmp) / (MaxAmp - MinAmp) * (maxAMP - 1));\r\n            }\r\n            //m_PeakData = Array.ConvertAll<double, double>(drawFreqAmp, value => (double)((value- MinAmp) * (maxAMP - 1) / (MaxAmp - MinAmp)));\r\n\r\n            FilterCScanPic(m_bmpCscan, m_PeakData, m_DrawImageStyle, colorBar, wd ...
#     'method_prefix': 'public static',
#     'method_param': '(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            )'},
#    {'method_name': 'DrawDiffFreqDomainImage',
#     'method_comment': '',
# ...
#     'method_comment': '',
#     'method_code': 'publicstaticvoidFindMaxPeakMinPeak(\r\n            int gateStartNum\r\n            , int gateEndNum\r\n            , byte[] ascandata\r\n            , WaveDataStyle wd\r\n            , int offset\r\n            , int maxamp\r\n            , out byte maxPeak\r\n            , out byte minPeak\r\n            , out int maxPosition\r\n            , out int minPosition\r\n            , int step = 10\r\n            ){\r\n\r\n            if (ascandata == null || ascandata.Length <= 0 || gateStartNum > ascandata.Length-1 || gateEndNum > ascandata.Length || ascandata.Max() == 0)\r\n            {\r\n                maxPeak = 0;\r\n                minPeak = 0;\r\n                maxPosition = 0;\r\n                minPosition = 0;\r\n                return;\r\n                //loopState.Stop();\r\n                //break;\r\n                //return;\r\n            }\r\n\r\n\r\n\r\n            byte byteTempMin = byte.MaxValue;\r\n            byte byteTempMax = byte.MinValue;\r\n\r\n\r\n            // 最大峰值出现位置的下标\r\n            int numMax = 0;\r\n            // 最小峰值出现位置的下标\r\n            int numMin = 0;\r\n\r\n            int initIndex_min = 0;\r\n            int initIndex_max = 0;\r\n\r\n\r\n\r\n            //粗找\r\n            for (int k = gateStartNum; k < gateEndNum; k += step)\r\n            {\r\n\r\n                byte byteTemp = ascandata[k];\r\n                byteTemp = (byte)DataUtils.GetActualAmp((int)wd, byteTemp, offset, maxamp);\r\n                //下限\r\n                if (byteTemp < byteTempMin)\r\n                {\r\n                    byteTempMin = byteTemp;\r\n                    initIndex_min = k;\r\n                }\r\n                //上限\r\n                if (byteTemp > byteTempMax)\r\n                {\r\n                    byteTempMax = byteTemp;\r\n                    initIndex_max = k;\r\n                }\r\n            }\r\n\r\n            numMin = initIndex_min;\r\n            numMax = initIndex_max;\r\n            //精细查找\r\n            //最小值查找\r\n            if (initIndex_min > 0 && initIndex_min < gateEndNum)\r\n            {\r\n                for (int k = Math.Max(initIndex_min - step, 0); k < Math.Min(initIndex_min + step, gateEndNum); k++)\r\n                {\r\n                    byte byteTemp = ascandata[k];\r\n                    byteTemp = (byte)DataUtils.GetActualAmp((int)wd, byteTemp, offset, maxamp);\r\n                    //下限\r\n                    if (byteTemp < byteTempMin)\r\n                    {\r\n                        byteTempMin = byteTemp;\r\n                        numMin = k;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else if (initIndex_min == 0)\r\n            {\r\n                for (int k = 0; k < initIndex_min + 2 * step; k++)\r\n                {\r\n                    byte byteTemp = ascandata[k];\r\n                    byteTemp = (byte)DataUtils.GetActualAmp((int)wd, byteTemp, offset, maxamp);\r\n                    //下限\r\n                    if (byteTemp < byteTempMin)\r\n                    {\r\n                        byteTempMin = byteTemp;\r\n                        numMin = k;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else if (initIndex_min == gateEndNum - 1)\r\n            {\r\n                for (int k = initIndex_min - 2 * step; k < initIndex_min; k++)\r\n                {\r\n                    byte byteTemp = ascandata[k];\r\n                    byteTemp = (byte)DataUtils.GetActualAmp((int)wd, byteTemp, offset, maxamp);\r\n                    //下限\r\n                    if (byteTemp < byteTempMin)\r\n                    {\r\n                        byteTempMin = byteTemp;\r\n                        numMin = k;\r\n                    }\r\n\r\n                }\r\n            }\r\n            //精细查找，最大\r\n            if (initIndex_max > 0 && initIndex_max < gateEndNum)\r\n            {\r\n                for (int k = Math.Max(initIndex_max - step, 0); k < Ma ...
#     'method_prefix': 'public static',
#     'method_param': '(\r\n            int gateStartNum\r\n            , int gateEndNum\r\n            , byte[] ascandata\r\n            , WaveDataStyle wd\r\n            , int offset\r\n            , int maxamp\r\n            , out byte maxPeak\r\n            , out byte minPeak\r\n            , out int maxPosition\r\n            , out int minPosition\r\n            , int step = 10\r\n            )'},
#    {'method_name': 'NumConversionTo256ForColorBar',
#     'method_comment': '',
#     'method_code': 'publicstaticintNumConversionTo256ForColorBar(double zerotoonev, short maxv){\r\n            return (int)Math.Floor(zerotoonev * maxv);\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double zerotoonev, short maxv)'},
#    {'method_name': 'CalPeakData',
#     'method_comment': '',
#     'method_code': 'publicstaticdoubleCalPeakData(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       ){\r\n\r\n            if (ascandata == null || ascandata.Length <= 0)\r\n            {\r\n                maxIndex = 0;\r\n                return 0;\r\n            }\r\n           \r\n            //double peakdata = 0;\r\n            // 最大峰值出现位置的下标\r\n            int numMax = 0;\r\n            // 最小峰值出现位置的下标\r\n            int numMin = 0;\r\n\r\n            //double temp = 0;\r\n            double tempMax = double.MinValue;\r\n            double tempMin = double.MaxValue;\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n\r\n            int lengthNum;\r\n            if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum) > ascandata.GetLength(0))\r\n            {\r\n                lengthNum = ascandata.GetLength(0);\r\n            }\r\n            else\r\n            {\r\n                lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum;\r\n            }\r\n\r\n            byte byteMinThreshold = (byte)(NumConversionTo256(-thresholdData, wd));//- offsetToZero\r\n            byteMinThreshold = (byte)(byteMinThreshold < 1 ? 1 : byteMinThreshold);\r\n            byte byteMaxThreshold = (byte)(NumConversionTo256(thresholdData, wd));//- offsetToZero\r\n            byte byteTempMax = byte.MinValue;\r\n            byte byteTempMin = byte.MaxValue;\r\n\r\n            byte bytePeakdata = 0;\r\n\r\n            int iStart = gateStartNum;\r\n            if (FSFGate.m_GateIsActived)\r\n            {\r\n                iStart = Math.Max(curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum, 0);\r\n            }\r\n\r\n\r\n\r\n            //查找门限中的负向幅值和正向幅值及其到达下标（时间）\r\n            FindMaxPeakMinPeak(\r\n                iStart\r\n                , lengthNum\r\n                , ascandata\r\n                , wd\r\n                , offsetToZero\r\n                , maxAMP\r\n                , out byteTempMax\r\n                , out byteTempMin\r\n                , out numMax\r\n                , out numMin\r\n\r\n                );\r\n            maxIndex = numMax;\r\n            double tof = 0;\r\n            //根据不同的闸门模式，取峰值\r\n            switch (gateMode)\r\n            {\r\n                case AmplitudeMode.PostivePeak://正向峰值\r\n                    bytePeakdata = byteTempMax;\r\n                    if (bytePeakdata < byteMaxThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.NegativePeak://负向峰值\r\n                    bytePeakdata = byteTempMin;\r\n\r\n                    if (bytePeakdata > byteMinThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.PeaktoPeak://0-255,峰峰值\r\n                    bytePeakdata = (byte)(byteTempMax - byteTempMin);\r\n\r\n                    if (bytePeakdata < (byteMaxThreshold - byteMinThreshold))\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n\r\n                case AmplitudeMode.MaxPeak://最大峰值\r\n\r\n                    bytePeakdata = (byte)Math.Max(byteTempMax, maxAMP - byteTempMin);\r\n\r\n                    if ...
#     'method_prefix': 'public static',
#     'method_param': '(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       )'},
#    {'method_name': 'NumConversionTo512',
#     'method_comment': '',
#     'method_code': 'publicstaticintNumConversionTo512(double m_PeakData){\r\n            return NumConversionToData(m_PeakData, 512, WaveDataStyle.RF);\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double m_PeakData)'},
#    {'method_name': 'NumConversionTo256',
#     'method_comment': '',
#     'method_code': 'publicstaticintNumConversionTo256(double m_PeakData, WaveDataStyle wd){\r\n            return NumConversionToData(m_PeakData, 256, wd);\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double m_PeakData, WaveDataStyle wd)'},
#    {'method_name': 'NumConversionToData',
#     'method_comment': '',
#     'method_code': 'publicstaticintNumConversionToData(double value, short data, WaveDataStyle wd){\r\n            int result = 0;\r\n            if (wd == WaveDataStyle.RF)\r\n            {\r\n\r\n                if (value < -1) { value = -1; }\r\n                if (value > 1) { value = 1; }\r\n                result = (int)(Math.Floor(value * data / 2) + data / 2);\r\n            }\r\n            else\r\n            {\r\n                result = (int)(value * data);\r\n            }\r\n            return result;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double value, short data, WaveDataStyle wd)'},
#    {'method_name': 'DrawCscanOnly',
#     'method_comment': '',
#     'method_code': 'publicstaticBitmapDrawCscanOnly(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd){\r\n            for (int j = 0; j < m_IndexNum; j++)\r\n            {\r\n                for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexOfAScan = j * m_ScanNum + i;\r\n                    if (m_GateMode == AmplitudeMode.PostivePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.PeaktoPeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = (m_Data[i][ j, 0] - m_Data[i][ j, 1]) / 2 / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.NegativePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.MaxPeak)\r\n                    {\r\n                        if (m_Data[i][j, 0] > (-m_Data[i][ j, 1]))\r\n                        {\r\n                            m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                        }\r\n                        else\r\n                        {\r\n                            m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                        }\r\n                    }\r\n                    // 根据每个信号的峰值绘制图像\r\n                    //m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[i, j], maxVoltage, m_GateMode, m_DrawImageStyle));\r\n                    m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[indexOfAScan], m_DrawImageStyle, colorBar, wd));\r\n                }\r\n            }\r\n\r\n\r\n\r\n\r\n\r\n\r\n            if (m_originBitmap != null)\r\n            {\r\n                m_originBitmap.Dispose();\r\n            }\r\n            m_originBitmap = new Bitmap(m_bmpCscan, m_bmpCscan.Width, m_bmpCscan.Height);\r\n\r\n            return m_originBitmap;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd)'},
#    {'method_name': 'GetGateStartNum',
#     'method_comment': '',
#     'method_code': 'publicstaticintGetGateStartNum(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart){\r\n            if (timeStart > totalTimeLen)\r\n            {\r\n                timeStart = totalTimeLen / 2;\r\n            }\r\n            int GateStartNum = (int)(timeStart * AScanCount / totalTimeLen);\r\n            \r\n            // 如果波形开始时间 + 同步闸门开始位置 + 数据闸门开始位置 《 0\r\n            int FSFGatePosition = FSFGate.m_CurFSFFirstPosition;\r\n            if (FSFGatePosition + FSFGate.m_iUseBottomWave * GateStartNum < 0)\r\n            {\r\n                // 数据闸门开始位置 = - 同步闸门开始位置 - 波形开始时间(0)\r\n                //GateStartNum = -FSFGatePosition - displaystart;\r\n                GateStartNum = -FSFGatePosition - displaystart;\r\n                if (-1 == FSFGate.m_iUseBottomWave)//底波\r\n                {\r\n                    GateStartNum = 0;\r\n                }\r\n                else\r\n                {\r\n                    GateStartNum = FSFGatePosition;//表面波\r\n                }\r\n            }\r\n            return GateStartNum;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart)'},
#    {'method_name': 'GetGateLengthNum',
#     'method_comment': '',
#     'method_code': 'publicstaticintGetGateLengthNum(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum){\r\n            // 数据闸门长度 = 闸门长度 * A信号数据长度 / 采样长度\r\n            int GateLengthNum = (int)((gatelen) * AScanCount / totalTimeLen);\r\n\r\n            // 波形起始时间 +同步闸门开始位置索引 + 数据闸门开始位置 + 数据闸门长度 》 A信号数据长度\r\n            if ((displaystart + FSFGatePosition + gateStartNum + GateLengthNum) > AScanCount)\r\n            {\r\n                // 数据闸门长度 = A信号数据长度 - 同步闸门开始位置索引 - 数据闸门开始位置 - 波形起始时间\r\n                GateLengthNum = AScanCount - FSFGatePosition - gateStartNum - displaystart;\r\n            }\r\n            //存文件错误\r\n            if (GateLengthNum < 0)\r\n            {\r\n                GateLengthNum = AScanCount - gateStartNum;\r\n            }\r\n            return GateLengthNum;\r\n        }',
#     'method_prefix': 'public static',
#     'method_param': '(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum)'}]}]

# %% [markdown]
# ### 2.4 项目分析
#
# 1. 从项目根目录遍历文件树，构建项目文件树
# 2. 结合项目结构以及各个代码片段中的`using`情况，构建项目文件引用树

# %%
if not os.path.isdir('../data/processed'):
    os.mkdir('../data/processed')

# %%
root_path = '../data/AMC/'

# %%
cs_files = []

# %%
def folder_walk(root_folder,file_lst):
    for path,folder_lst,fname_lst in os.walk(root_folder):
        for fname in fname_lst:
            if fname.endswith('.cs'):
                file_lst.append(os.path.join(path,fname))
    return file_lst

# %%
folder_walk(root_folder=root_path, file_lst=cs_files)
# Out:
# ['../data/AMC/AlgorithmLib\\CScanPicFunction.cs',
#  '../data/AMC/AlgorithmLib\\CScanPicFunctionGPU - 副本 (2).cs',
#  '../data/AMC/AlgorithmLib\\CScanPicFunctionGPU - 副本.cs',
#  '../data/AMC/AlgorithmLib\\CScanPicFunctionGPU.cs',
#  '../data/AMC/AlgorithmLib\\UltrasonicalPeakDll.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/AlgorithmLib\\Properties\\Resources.Designer.cs',
#  '../data/AMC/AlgorithmLib\\Properties\\Settings.Designer.cs',
#  '../data/AMC/AMC\\About.cs',
#  '../data/AMC/AMC\\About.Designer.cs',
#  '../data/AMC/AMC\\AreaEdit.cs',
#  '../data/AMC/AMC\\AreaEdit.designer.cs',
#  '../data/AMC/AMC\\AsResult.cs',
#  '../data/AMC/AMC\\AsResult.Designer.cs',
#  '../data/AMC/AMC\\BScanImageForm.cs',
#  '../data/AMC/AMC\\BScanImageForm.Designer.cs',
#  '../data/AMC/AMC\\CheckUserFrm.cs',
#  '../data/AMC/AMC\\CheckUserFrm.Designer.cs',
#  '../data/AMC/AMC\\CScanPic.cs',
#  '../data/AMC/AMC\\CScanPic.Designer.cs',
#  '../data/AMC/AMC\\ExternalIterface.cs',
#  '../data/AMC/AMC\\FftForm.cs',
#  '../data/AMC/AMC\\FftForm.Designer.cs',
#  '../data/AMC/AMC\\Form1.cs',
#  '../data/AMC/AMC\\Form1.Designer.cs',
#  '../data/AMC/AMC\\Form1_AutoScan.Designer.cs',
#  '../data/AMC/AMC\\Form1_DataManager.Designer.cs',
#  '../data/AMC/AMC\\Form1_DataProcess.Designer.cs',
#  '../data/AMC/AMC\\Form1_Gail.Designer.cs',
#  '../data/AMC/AMC\\Form1_Task.Designer.cs',
#  '../data/AMC/AMC\\Form1_Test.Designer.cs',
#  '../data/AMC/AMC\\FreqPara.cs',
#  '../data/AMC/AMC\\FreqPara.Designer.cs',
#  '../data/AMC/AMC\\frmMark.cs',
#  '../data/AMC/AMC\\frmMark.Designer.cs',
#  '../data/AMC/AMC\\frmRemarkList.cs',
#  '../data/AMC/AMC\\frmRemarkList.Designer.cs',
#  '../data/AMC/AMC\\JSRControlForm.cs',
#  '../data/AMC/AMC\\JSRControlForm.Designer.cs',
#  '../data/AMC/AMC\\LayoutControl1.cs',
#  '../data/AMC/AMC\\LayoutControl1.designer.cs',
#  '../data/AMC/AMC\\LayoutSet.cs',
#  '../data/AMC/AMC\\LayoutSet.designer.cs',
#  '../data/AMC/AMC\\LoadingForm.cs',
#  '../data/AMC/AMC\\LoadingForm.Designer.cs',
#  '../data/AMC/AMC\\LoadingHelper.cs',
#  '../data/AMC/AMC\\LoginForm.cs',
#  '../data/AMC/AMC\\LoginForm.designer.cs',
#  '../data/AMC/AMC\\MeasurePareFrm.cs',
#  '../data/AMC/AMC\\MeasurePareFrm.Designer.cs',
#  '../data/AMC/AMC\\MeasureVzForm.cs',
#  '../data/AMC/AMC\\MeasureVzForm.Designer.cs',
#  '../data/AMC/AMC\\MyAscan.cs',
#  '../data/AMC/AMC\\MyAscan.Designer.cs',
#  '../data/AMC/AMC\\MyAscanOffline.cs',
#  '../data/AMC/AMC\\MyAscanOffline.Designer.cs',
#  '../data/AMC/AMC\\OfflineCScanPic.cs',
#  '../data/AMC/AMC\\OfflineCScanPic.Designer.cs',
#  '../data/AMC/AMC\\OutlookSettingForm.cs',
#  '../data/AMC/AMC\\OutlookSettingForm.Designer.cs',
#  '../data/AMC/AMC\\Program.cs',
#  '../data/AMC/AMC\\Resource1.Designer.cs',
#  '../data/AMC/AMC\\SecondFrm.cs',
#  '../data/AMC/AMC\\SecondFrm.Designer.cs',
#  '../data/AMC/AMC\\SelectImgStyle.cs',
#  '../data/AMC/AMC\\SelectImgStyle.Designer.cs',
#  '../data/AMC/AMC\\SelfDefineImgSizeFrm.cs',
#  '../data/AMC/AMC\\SelfDefineImgSizeFrm.Designer.cs',
#  '../data/AMC/AMC\\SuspendForm.cs',
#  '../data/AMC/AMC\\SuspendForm.Designer.cs',
#  '../data/AMC/AMC\\UMSpdf.cs',
#  '../data/AMC/AMC\\UMSpdf.Designer.cs',
#  '../data/AMC/AMC\\UserControlRegion.cs',
#  '../data/AMC/AMC\\UserControlRegion.designer.cs',
#  '../data/AMC/AMC\\WaitForm1.cs',
#  '../data/AMC/AMC\\WaitForm1.designer.cs',
#  '../data/AMC/AMC\\WaveOffsetForm.cs',
#  '../data/AMC/AMC\\WaveOffsetForm.Designer.cs',
#  '../data/AMC/AMC\\WaveSetting.cs',
#  '../data/AMC/AMC\\WorkPartSet.cs',
#  '../data/AMC/AMC\\WorkPartSet.designer.cs',
#  '../data/AMC/AMC\\WorkpieceStatus.cs',
#  '../data/AMC/AMC\\WorkpieceStatus.Designer.cs',
#  '../data/AMC/AMC\\AutoScan\\AbstractAutoScanTask.cs',
#  '../data/AMC/AMC\\AutoScan\\AutoScanLog.cs',
#  '../data/AMC/AMC\\AutoScan\\AutoScanParallelTask.cs',
#  '../data/AMC/AMC\\AutoScan\\AutoScanSerialTask.cs',
#  '../data/AMC/AMC\\AutoScan\\PlcCommand.cs',
#  '../data/AMC/AMC\\AutoScan\\PointXYZ.cs',
#  '../data/AMC/AMC\\AutoScan\\RobotStatus.cs',
#  '../data/AMC/AMC\\AutoScan\\UI_MonitorIO.cs',
#  '../data/AMC/AMC\\AutoScan\\UI_MonitorIO.designer.cs',
#  '../data/AMC/AMC\\AutoScan\\WorkPieceAuto.cs',
#  '../data/AMC/AMC\\DM\\AdaptFont.cs',
#  '../data/AMC/AMC\\DM\\AuthorityControl.cs',
#  '../data/AMC/AMC\\DM\\EnumClass.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc_Check.cs',
#  '../data/AMC/AMC\\DM\\Form_Acc_Check.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Axises.cs',
#  '../data/AMC/AMC\\DM\\Form_Axises.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Axises_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Axises_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Cells_Edit.cs',
#  '../data/AMC/AMC\\DM\\Form_Cells_Edit.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Couplants.cs',
#  '../data/AMC/AMC\\DM\\Form_Couplants.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Couplants_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Couplants_Add.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceApps.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceApps.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceApps_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceApps_Add.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceEntities.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceEntities.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceEntities_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_DeviceEntities_Add.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_ExceptionHandling.cs',
#  '../data/AMC/AMC\\DM\\Form_ExceptionHandling.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Globalpars.cs',
#  '../data/AMC/AMC\\DM\\Form_Globalpars.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Globalpars_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Globalpars_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_IOInfo.cs',
#  '../data/AMC/AMC\\DM\\Form_IOInfo.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_IOInfo_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_IOInfo_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_KeyParameters.cs',
#  '../data/AMC/AMC\\DM\\Form_KeyParameters.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_KeyParameters_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_KeyParameters_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_LayControls.cs',
#  '../data/AMC/AMC\\DM\\Form_LayControls.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Layouts.cs',
#  '../data/AMC/AMC\\DM\\Form_Layouts.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Layouts_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Layouts_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_LogConfigs.cs',
#  '../data/AMC/AMC\\DM\\Form_LogConfigs.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_LogConfigs_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_LogConfigs_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Materials.cs',
#  '../data/AMC/AMC\\DM\\Form_Materials.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Materials_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Materials_Add.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_MeasureThick.cs',
#  '../data/AMC/AMC\\DM\\Form_MeasureThick.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Modules.cs',
#  '../data/AMC/AMC\\DM\\Form_Modules.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Modules_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Modules_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_MonitorParas.cs',
#  '../data/AMC/AMC\\DM\\Form_MonitorParas.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Productlines.cs',
#  '../data/AMC/AMC\\DM\\Form_Productlines.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Productlines_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Productlines_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Products.cs',
#  '../data/AMC/AMC\\DM\\Form_Products.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Products_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Products_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_RobotTest.cs',
#  '../data/AMC/AMC\\DM\\Form_RobotTest.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Roles.cs',
#  '../data/AMC/AMC\\DM\\Form_Roles.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Roles_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Roles_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Role_Auth.cs',
#  '../data/AMC/AMC\\DM\\Form_Role_Auth.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Scanareas.cs',
#  '../data/AMC/AMC\\DM\\Form_Scanareas.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Scanareas_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Scanareas_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Traj.cs',
#  '../data/AMC/AMC\\DM\\Form_Traj.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajAxis.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajAxis.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajAxises.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajAxises.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajPoints.cs',
#  '../data/AMC/AMC\\DM\\Form_TrajPoints.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Traj_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Traj_Add.Designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Users.cs',
#  '../data/AMC/AMC\\DM\\Form_Users.designer.cs',
#  '../data/AMC/AMC\\DM\\Form_Users_Add.cs',
#  '../data/AMC/AMC\\DM\\Form_Users_Add.designer.cs',
#  '../data/AMC/AMC\\DM\\TrajAxisUI.cs',
#  '../data/AMC/AMC\\DM\\TrajAxisUI.Designer.cs',
#  '../data/AMC/AMC\\LayControl\\LeftRightAxis.cs',
#  '../data/AMC/AMC\\LayControl\\LeftRightAxis.Designer.cs',
#  '../data/AMC/AMC\\LayControl\\MontionCardUI.cs',
#  '../data/AMC/AMC\\LayControl\\MontionCardUI.Designer.cs',
#  '../data/AMC/AMC\\LayControl\\UpDownAxis.cs',
#  '../data/AMC/AMC\\LayControl\\UpDownAxis.Designer.cs',
#  '../data/AMC/AMC\\MultiArea\\OneScanArea.cs',
#  '../data/AMC/AMC\\MultiArea\\OneWorkPart.cs',
#  '../data/AMC/AMC\\MultiArea\\ScanLayoutInfo.cs',
#  '../data/AMC/AMC\\MultiArea\\ScanLayoutSetting.cs',
#  '../data/AMC/AMC\\MultiArea\\WorkParts.cs',
#  '../data/AMC/AMC\\MultiAreaXml\\SerializeScanLayoutXml.cs',
#  '../data/AMC/AMC\\MultiAreaXml\\SerializeWorkPartsXml.cs',
#  '../data/AMC/AMC\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/AMC\\Properties\\Resources.Designer.cs',
#  '../data/AMC/AMC\\Properties\\Settings.Designer.cs',
#  '../data/AMC/AMC\\SystemPara\\Form_GlobalparaDataType.cs',
#  '../data/AMC/AMC\\SystemPara\\Form_GlobalparaDataType.Designer.cs',
#  '../data/AMC/AMC\\SystemPara\\GlobalParameter.cs',
#  '../data/AMC/AMC\\SystemPara\\GlobalParameter.Designer.cs',
#  '../data/AMC/AMC\\SystemPara\\SystemParameter.cs',
#  '../data/AMC/AMC\\WorkPiece\\UserControlWorkPiece.cs',
#  '../data/AMC/AMC\\WorkPiece\\UserControlWorkPiece.Designer.cs',
#  '../data/AMC/AMC\\WorkPiece\\UserControlWorkPieceStation.cs',
#  '../data/AMC/AMC\\WorkPiece\\UserControlWorkPieceStation.Designer.cs',
#  '../data/AMC/AMC\\WorkPiece\\WorkPiece.cs',
#  '../data/AMC/Common\\DataCollectCard.cs',
#  '../data/AMC/Common\\gclib-bak.cs',
#  '../data/AMC/Common\\gclib.cs',
#  '../data/AMC/Common\\JSRPulseDll.cs',
#  '../data/AMC/Common\\JSRPulser.cs',
#  '../data/AMC/Common\\MotionAxis.cs',
#  '../data/AMC/Common\\MotionAxisUsingDll.cs',
#  '../data/AMC/Common\\PCIe9802Import.cs',
#  '../data/AMC/Common\\PCIe9802SImport.cs',
#  '../data/AMC/Common\\WorkPiece.cs',
#  '../data/AMC/Common\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/DatacardLib\\AbstractDataCard.cs',
#  '../data/AMC/DatacardLib\\RDConvertType.cs',
#  '../data/AMC/DatacardLib\\RDDataCardEnums.cs',
#  '../data/AMC/DatacardLib\\RDDataCardParameters.cs',
#  '../data/AMC/DatacardLib\\RDDataType.cs',
#  '../data/AMC/DatacardLib\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DatacardLib\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DatacardLib\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DatacardLib\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DatacardLib\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DatacardLib\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DatacardLib\\PCIE4619\\ImportPCIe4619.cs',
#  '../data/AMC/DatacardLib\\PCIE9802\\ImportPCIe9802.cs',
#  '../data/AMC/DatacardLib\\PCIE9802\\PCIE9802_Enum.cs',
#  '../data/AMC/DatacardLib\\PCIE9802S\\ImportPCIe9802S.cs',
#  '../data/AMC/DatacardLib\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/DatacardLib\\USS8802\\ImportUSS8802.cs',
#  '../data/AMC/Devices\\AbstractDevice.cs',
#  '../data/AMC/Devices\\PointXYZ.cs',
#  '../data/AMC/Devices\\PulserType.cs',
#  '../data/AMC/Devices\\DeviceException\\DeviceException.cs',
#  '../data/AMC/Devices\\IO\\AbstractIO.cs',
#  '../data/AMC/Devices\\IO\\GailIO\\GailIO.cs',
#  '../data/AMC/Devices\\IO\\SiemensIO\\SiemensIO.cs',
#  '../data/AMC/Devices\\MeasureThickDevice\\GlueMeasurePara.cs',
#  '../data/AMC/Devices\\MeasureThickDevice\\MeasureThickDeivce.cs',
#  '../data/AMC/Devices\\MotionCard\\AbstractMotionCard.cs',
#  '../data/AMC/Devices\\MotionCard\\ExtAxises.cs',
#  '../data/AMC/Devices\\MotionCard\\MotionAxises.cs',
#  '../data/AMC/Devices\\MotionCard\\MultiAxisPara.cs',
#  '../data/AMC/Devices\\MotionCard\\GailMotionCard\\GailMotionCard.cs',
#  '../data/AMC/Devices\\MotionCard\\GailMotionCard\\gclib.cs',
#  '../data/AMC/Devices\\MotionCard\\RobotMotionCard\\AxisArgo.cs',
#  '../data/AMC/Devices\\MotionCard\\RobotMotionCard\\ConstValue.cs',
#  '../data/AMC/Devices\\MotionCard\\RobotMotionCard\\MatrixClass.cs',
#  '../data/AMC/Devices\\MotionCard\\RobotMotionCard\\RobotMotionCard - 副本_0423.cs',
#  '../data/AMC/Devices\\MotionCard\\RobotMotionCard\\RobotMotionCard.cs',
#  '../data/AMC/Devices\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Devices\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Devices\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Devices\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Devices\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Devices\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Devices\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/Devices\\ScancodeGun\\AbstractScanCode.cs',
#  '../data/AMC/Devices\\ScancodeGun\\KeyenceScanCode.cs',
#  '../data/AMC/Devices\\ScancodeGun\\ScanHomeScanCode.cs',
#  '../data/AMC/DM\\Pair.cs',
#  '../data/AMC/DM\\SqliteTableName.cs',
#  '../data/AMC/DM\\dao\\AccessoriesDao.cs',
#  '../data/AMC/DM\\dao\\AxisesDao.cs',
#  '../data/AMC/DM\\dao\\BaseDao.cs',
#  '../data/AMC/DM\\dao\\CellsDao.cs',
#  '../data/AMC/DM\\dao\\CommonDao.cs',
#  '../data/AMC/DM\\dao\\CouplantsDao.cs',
#  '../data/AMC/DM\\dao\\DeviceAppsDao.cs',
#  '../data/AMC/DM\\dao\\DeviceEntitiesDao.cs',
#  '../data/AMC/DM\\dao\\GlobalparsDao.cs',
#  '../data/AMC/DM\\dao\\IncludeInQueryAttribute.cs',
#  '../data/AMC/DM\\dao\\IOInfosDao.cs',
#  '../data/AMC/DM\\dao\\KeyParametersDao.cs',
#  '../data/AMC/DM\\dao\\LayControlsDao.cs',
#  '../data/AMC/DM\\dao\\LayoutsDao.cs',
#  '../data/AMC/DM\\dao\\LogConfigsDao.cs',
#  '../data/AMC/DM\\dao\\MaterialsDao.cs',
#  '../data/AMC/DM\\dao\\ModulesDao.cs',
#  '../data/AMC/DM\\dao\\MotionTrajsDao.cs',
#  '../data/AMC/DM\\dao\\ProductlinesDao.cs',
#  '../data/AMC/DM\\dao\\ProductsDao.cs',
#  '../data/AMC/DM\\dao\\RolesDao.cs',
#  '../data/AMC/DM\\dao\\ScanareasDao.cs',
#  '../data/AMC/DM\\dao\\SQLiteBaseDao.cs',
#  '../data/AMC/DM\\dao\\SQLiteConnectionPool.cs',
#  '../data/AMC/DM\\dao\\TrajAxisesDao.cs',
#  '../data/AMC/DM\\dao\\TrajPointsDao.cs',
#  '../data/AMC/DM\\dao\\UsersDao.cs',
#  '../data/AMC/DM\\entity\\AbstractSQLiteEntity.cs',
#  '../data/AMC/DM\\entity\\Accessories.cs',
#  '../data/AMC/DM\\entity\\Axises.cs',
#  '../data/AMC/DM\\entity\\Cells.cs',
#  '../data/AMC/DM\\entity\\Couplants.cs',
#  '../data/AMC/DM\\entity\\DeviceApps.cs',
#  '../data/AMC/DM\\entity\\DeviceEntities.cs',
#  '../data/AMC/DM\\entity\\Globalpars.cs',
#  '../data/AMC/DM\\entity\\IOInfos.cs',
#  '../data/AMC/DM\\entity\\KeyParameters.cs',
#  '../data/AMC/DM\\entity\\LayControls.cs',
#  '../data/AMC/DM\\entity\\Layouts.cs',
#  '../data/AMC/DM\\entity\\LogConfigs.cs',
#  '../data/AMC/DM\\entity\\Materials.cs',
#  '../data/AMC/DM\\entity\\Modules.cs',
#  '../data/AMC/DM\\entity\\MotionAxis.cs',
#  '../data/AMC/DM\\entity\\MotionTrajs.cs',
#  '../data/AMC/DM\\entity\\Productlines.cs',
#  '../data/AMC/DM\\entity\\Products.cs',
#  '../data/AMC/DM\\entity\\RelationTrajAndTrajPoint.cs',
#  '../data/AMC/DM\\entity\\Roles.cs',
#  '../data/AMC/DM\\entity\\Scanareas.cs',
#  '../data/AMC/DM\\entity\\TrajAxises.cs',
#  '../data/AMC/DM\\entity\\TrajPoints.cs',
#  '../data/AMC/DM\\entity\\Users.cs',
#  '../data/AMC/DM\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DM\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DM\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DM\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DM\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DM\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DM\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/DM\\service\\AccessoriesService.cs',
#  '../data/AMC/DM\\service\\AxisesService.cs',
#  '../data/AMC/DM\\service\\CellsService.cs',
#  '../data/AMC/DM\\service\\CommonService.cs',
#  '../data/AMC/DM\\service\\CouplantsService.cs',
#  '../data/AMC/DM\\service\\DeviceAppsService.cs',
#  '../data/AMC/DM\\service\\DeviceEntitiesService.cs',
#  '../data/AMC/DM\\service\\GlobalparsService.cs',
#  '../data/AMC/DM\\service\\IOInfosService.cs',
#  '../data/AMC/DM\\service\\ISqliteService.cs',
#  '../data/AMC/DM\\service\\KeyParametersService.cs',
#  '../data/AMC/DM\\service\\LayControlsService.cs',
#  '../data/AMC/DM\\service\\LayoutsService.cs',
#  '../data/AMC/DM\\service\\LogConfigService.cs',
#  '../data/AMC/DM\\service\\MaterialsService.cs',
#  '../data/AMC/DM\\service\\ModulesService.cs',
#  '../data/AMC/DM\\service\\MotionTrajsService.cs',
#  '../data/AMC/DM\\service\\ProductlinesService.cs',
#  '../data/AMC/DM\\service\\ProductsService.cs',
#  '../data/AMC/DM\\service\\RolesService.cs',
#  '../data/AMC/DM\\service\\ScanareasService.cs',
#  '../data/AMC/DM\\service\\TrajAxisesService.cs',
#  '../data/AMC/DM\\service\\TrajPointsService.cs',
#  '../data/AMC/DM\\service\\UsersService.cs',
#  '../data/AMC/DM\\service\\impl\\AccessoriesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\AxisesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\CellsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\CommonServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\CouplantsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\DeviceAppsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\DeviceEntitiesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\GlobalparsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\IOInfosServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\KeyParametersServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\LayControlsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\LayoutsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\LogConfigServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\MaterialsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\ModulesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\MotionTrajsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\ProductlinesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\ProductsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\RolesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\ScanareasServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\SqliteServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\TrajAxisesServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\TrajPointsServiceImpl.cs',
#  '../data/AMC/DM\\service\\impl\\UsersServiceImpl.cs',
#  '../data/AMC/GitId\\Link.cs',
#  '../data/AMC/GitId\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/GitId\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/GitId\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/GitId\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/GitId\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/GitId\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/GitId\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/Global\\AppConfig.cs',
#  '../data/AMC/Global\\Config.cs',
#  '../data/AMC/Global\\DatatypeDefine.cs',
#  '../data/AMC/Global\\FreqInfo.cs',
#  '../data/AMC/Global\\Global.cs',
#  '../data/AMC/Global\\IntPtrType.cs',
#  '../data/AMC/Global\\JSRParas.cs',
#  '../data/AMC/Global\\LockGate.cs',
#  '../data/AMC/Global\\Message.cs',
#  '../data/AMC/Global\\MyBackPanel.cs',
#  '../data/AMC/Global\\MyPanelGroup.cs',
#  '../data/AMC/Global\\MyTablePage.cs',
#  '../data/AMC/Global\\OutLineShareParamters.cs',
#  '../data/AMC/Global\\ReadDataType.cs',
#  '../data/AMC/Global\\RubberLine.cs',
#  '../data/AMC/Global\\WorkPartComboxItem.cs',
#  '../data/AMC/Global\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/Measure\\AbsGeomController.cs',
#  '../data/AMC/Measure\\GeomDrawRegion.cs',
#  '../data/AMC/Measure\\GeomDrawRegion.Designer.cs',
#  '../data/AMC/Measure\\GeomDrawRegionController.cs',
#  '../data/AMC/Measure\\RefreshForm.cs',
#  '../data/AMC/Measure\\Controller\\BScanCtrller.cs',
#  '../data/AMC/Measure\\Controller\\CScanOfflineCtrller.cs',
#  '../data/AMC/Measure\\Controller\\CscanOnlineCtrller.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawAScanLine.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawCross.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawGate.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawHorLine.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawVerLine.cs',
#  '../data/AMC/Measure\\DrawObjects\\DrawVerLineCM.cs',
#  '../data/AMC/Measure\\DrawObjects\\IDraw.cs',
#  '../data/AMC/Measure\\DrawObjects\\TransMatrix.cs',
#  '../data/AMC/Measure\\DrawObjects\\Bitmaps\\CBitmapAScan.cs',
#  '../data/AMC/Measure\\DrawObjects\\Bitmaps\\CBitmapEightBits.cs',
#  '../data/AMC/Measure\\DrawObjects\\Bitmaps\\RefSize.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\FineSweepRectangle.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\MeasureBase.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\MeasureCircle.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\MeasureLine.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\MeasureMultLine.cs',
#  '../data/AMC/Measure\\DrawObjects\\Measure\\MeasureRectangle.cs',
#  '../data/AMC/Measure\\DrawObjects\\Tools\\ITool.cs',
#  '../data/AMC/Measure\\DrawObjects\\Tools\\ToolPointer.cs',
#  '../data/AMC/Measure\\DrawObjects\\Xml\\IXmlObject.cs',
#  '../data/AMC/Measure\\DrawObjects\\Xml\\XRemarkGroup.cs',
#  '../data/AMC/Measure\\DrawObjects\\Xml\\XRemarkGroups.cs',
#  '../data/AMC/Measure\\DrawObjects\\Xml\\XRemarks.cs',
#  '../data/AMC/Measure\\DrawObjects\\Xml\\XSyncGate.cs',
#  '../data/AMC/Measure\\Managers\\ActionManager.cs',
#  '../data/AMC/Measure\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/PLCLib\\EnumExtensions.cs',
#  '../data/AMC/PLCLib\\PlcTool.cs',
#  '../data/AMC/PLCLib\\PlcTool.DataSet.cs',
#  '../data/AMC/PLCLib\\PlcTool.ReadAndWrite.cs',
#  '../data/AMC/PLCLib\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/PLCLib\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/PLCLib\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/PLCLib\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/PLCLib\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/PLCLib\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/PLCLib\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/Utils\\CommonUtil.cs',
#  '../data/AMC/Utils\\ComplexNumber.cs',
#  '../data/AMC/Utils\\ConvertType.cs',
#  '../data/AMC/Utils\\DataUtils.cs',
#  '../data/AMC/Utils\\DMUtils.cs',
#  '../data/AMC/Utils\\encrypt.cs',
#  '../data/AMC/Utils\\ExCircleQueue.cs',
#  '../data/AMC/Utils\\ExecAction.cs',
#  '../data/AMC/Utils\\FftAlgorithm.cs',
#  '../data/AMC/Utils\\Functions.cs',
#  '../data/AMC/Utils\\GZip.cs',
#  '../data/AMC/Utils\\JsonHelper.cs',
#  '../data/AMC/Utils\\Log.cs',
#  '../data/AMC/Utils\\LogAsync.cs',
#  '../data/AMC/Utils\\SystemInfo.cs',
#  '../data/AMC/Utils\\XmlHelper.cs',
#  '../data/AMC/Utils\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils\\obj\\x64\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils\\obj\\x64\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils\\obj\\x64\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils\\Properties\\AssemblyInfo.cs',
#  '../data/AMC/XmlConfigs\\AxisInfo.cs',
#  '../data/AMC/XmlConfigs\\AxisSetting.cs',
#  '../data/AMC/XmlConfigs\\Class1.cs',
#  '../data/AMC/XmlConfigs\\ConfigItem.cs',
#  '../data/AMC/XmlConfigs\\CorrectWave.cs',
#  '../data/AMC/XmlConfigs\\DPR.cs',
#  '../data/AMC/XmlConfigs\\DPRConfig.cs',
#  '../data/AMC/XmlConfigs\\DPRInfo.cs',
#  '../data/AMC/XmlConfigs\\Glconfiguration.cs',
#  '../data/AMC/XmlConfigs\\IndexAxis.cs',
#  '../data/AMC/XmlConfigs\\Laycontrol.cs',
#  '../data/AMC/XmlConfigs\\MotionLayout.cs',
#  '../data/AMC/XmlConfigs\\ScanAxis.cs',
#  '../data/AMC/XmlConfigs\\ScanSetting.cs',
#  '../data/AMC/XmlConfigs\\WaveInfo.cs',
#  '../data/AMC/XmlConfigs\\WaveSetting.cs',
#  '../data/AMC/XmlConfigs\\obj\\Debug\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs\\obj\\Debug\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs\\obj\\Debug\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs\\obj\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs\\obj\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs\\obj\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs\\obj\\x64\\Release\\TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs\\obj\\x64\\Release\\TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs\\obj\\x64\\Release\\TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs\\Properties\\AssemblyInfo.cs']

# %%
len(cs_files)
# Out:
# 570

# %%
cs_files = [i.replace('\\','/') for i in cs_files]

# %% [markdown]
# #### 项目分析并存储

# %%
cslang = tree_sitter.Language(tree_sitter_c_sharp.language())

parser = Parser(cslang)

content = []

for idx,file_path in enumerate(cs_files):
    if idx%1000==0:
        print(f'Hit:{idx}')
    with open(file_path, "rb") as f:
        ftree = parser.parse(f.read())
        
    node_dict = {
            'filename': '',
            'filepath': file_path,
            'source_reference':[],
            'source_comments': [],
            'source_class': []
        }
    node_dict['filename'] = file_path.split('/')[-1]
    node_dict['source_reference'] = extract_using_directives(ftree.root_node)
    node_dict['source_comments'] = extract_file_level_comments(ftree.root_node)
    node_dict['source_class'] = extract_class_info(ftree.root_node)
    content.append(node_dict)
# Out:
# Hit:0

# %% [markdown]
# ### 保存中间结果

# %%
import json

# %%
json.dump(content, open('../data/processed/amc-by-tree-sitter.json','w'))

# %%
# json.dump(cs_files, open('../data/processed/project-allfile.json','w'))

# %% [markdown]
# # 3. 引用关联
#
# 根据文件在头部声明的引用，将其与本地文件关联

# %%
for node in content:
    ref_key = '.'.join(node['filepath'].split('/')[3:]).removesuffix('.cs')
    namespace_key = '.'.join(node['filepath'].split('/')[3:]).removesuffix(f".{node['filename']}")
    node['reference_key'] = ref_key
    node['namespace_key'] = namespace_key

# %%
ref_dict = {}
for node in content:
    ref_dict[node['reference_key']] = {k:node[k] for k in node if k!='reference_key'}

# %%
list(ref_dict.values())[0]
# Out:
# {'filename': 'CScanPicFunction.cs',
#  'filepath': '../data/AMC/AlgorithmLib/CScanPicFunction.cs',
#  'source_reference': ['System.Collections.Generic',
#   'System.Diagnostics',
#   'System.Drawing',
#   'System.IO',
#   'System.Linq',
#   'System.Text',
#   'System.Threading',
#   'System.Threading.Tasks',
#   'System.Windows.Forms'],
#  'source_comments': [],
#  'source_class': [{'class_name': 'CScanPicFunction',
#    'class_comment': '',
#    'class_code': '{\r\n\r\n\r\n        /// <summary>\r\n        ///  在闸门内查找第一个与波形的交叉点\r\n        /// </summary>\r\n        /// <param name="threshValue">阈值(转换为0-2^N,N是卡的位数,譬如8位卡,就是256)</param>\r\n        /// <param name="gateLengthNum">闸门长度</param>\r\n        /// <param name="gateStartNum">闸门在A信号中的起始位置</param>\r\n        /// <param name="isPositiveThresh">计算正向阈值标志,true：正向;false:负向</param>\r\n        /// <param name="ascandata">A信号数据</param>\r\n        /// <returns></returns>\r\n        public static int FindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)\r\n        {\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos +=  ...
#    'methods': [{'method_name': 'FindFirstPostionInFSFGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                    if ((iPos + 1) < iposMax && ascandata[iPos + 1] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos + 1;\r\n                        bHasFound = true;\r\n    ...
#      'method_prefix': 'public static',
#      'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)'},
#     {'method_name': 'FindFirstPostionRelativeInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindFirstPostionRelativeInGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n\r\n\r\n            if (isPositiveThresh)//正向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] >= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n\r\n            if (!bHasFound) //如果没找到符合条件的值，则返回FSF闸门0 \r\n            {\r\n                iPos = gateStartNum;//相对于起点，这是绝对位置\r\n            }\r\n            return iPos - gateStartNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata)'},
#     {'method_name': 'CalCouplantDepth',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalCouplantDepth(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata){\r\n            int indexStartWave = FSFGate.m_GateStartNum;\r\n            //int indexSufaceWave = FSFGate.m_GateStartNum;\r\n            for (; indexStartWave < ascandata.Length; indexStartWave++)\r\n            {\r\n                if (ascandata[indexStartWave] >= FSFGate.ThreshAMP)\r\n                {\r\n                    break;\r\n                }\r\n            }\r\n            //for (; indexSufaceWave < Math.Min(FSFGate.m_GateStartNum + FSFGate.m_GateLengthNum, ascandata.Length); indexSufaceWave++)\r\n            //{\r\n            //    if (ascandata[indexSufaceWave] >= FSFGate.ThreshAMP)\r\n            //    {\r\n            //        break;\r\n            //    }\r\n\r\n            //}\r\n            return (Math.Abs(indexStartWave) * timeLen / ascandata.Length + timedelay) * v / 2;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata)'},
#     {'method_name': 'DataToColor',
#      'method_comment': '',
#      'method_code': 'publicstaticColorDataToColor(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res);\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                else\r\n                {\r\n                    if (res < 1)\r\n                    {\r\n                        res = 1;\r\n                    }\r\n                    if (res > 511)\r\n                    {\r\n                        res = 511;\r\n                    }\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                Color colorRet = Color.FromArgb(colorBar.m_CColorData.m_ColorTab[res]);\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'DataToColorForInt',
#      'method_comment': '',
#      'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'DataToColorForInt',
#      'method_comment': '',
#      'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = colorBar.m_CColorData.m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'OutOldColorBar',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidOutOldColorBar(){\r\n            double step = 0.25 / 63.75;\r\n            int R = 0, G = 0, B = 0;\r\n            double VoltageScope = 1.0;\r\n            for (double data = 0; data <= 1; data += step)\r\n            {\r\n\r\n                if (data <= 0)\r\n                    R = G = B = 0;\r\n                else if (data <= VoltageScope / 4)\r\n                {\r\n                    R = G = 0;\r\n                    B = Functions.RoundToInt(data * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope / 2)\r\n                {\r\n                    R = 0;\r\n                    G = Functions.RoundToInt((data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                    B = Functions.RoundToInt(255 - (data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope * 3 / 4)\r\n                {\r\n                    R = Functions.RoundToInt((data - VoltageScope / 2) * 255 * 4 / VoltageScope);\r\n                    G = 255;\r\n                    B = 0;\r\n                }\r\n\r\n                else if (data <= VoltageScope)\r\n                {\r\n                    R = 255;\r\n                    G = Functions.RoundToInt(255 - (data - VoltageScope * 3 / 4) * 255 * 4 / VoltageScope);\r\n                    B = 0;\r\n                }\r\n\r\n                else\r\n                {\r\n                    R = 255;\r\n                    G = 0;\r\n                    B = 0;\r\n                }\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '()'},
#     {'method_name': 'AdjustPeakData',
#      'method_comment': '',
#      'method_code': 'publicstaticdouble[]AdjustPeakData(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd){\r\n            int iLen = scanNum * indexNum;\r\n            double[] result = new double[iLen];\r\n            double min, max;\r\n            min = double.MaxValue;\r\n            max = double.MinValue;\r\n\r\n            for (int i = 0; i < iLen; i++) //先找到最大、最小值\r\n            {\r\n                if (data[i] > max)\r\n                {\r\n                    max = data[i];\r\n                }\r\n                if (data[i] < min)\r\n                {\r\n                    min = data[i];\r\n                }\r\n            }\r\n\r\n\r\n            double valZone = max - min;\r\n            for (int i = 0; i < iLen; i++)\r\n            {\r\n                result[i] = NumConversionTo256((data[i] - min) * m_MaxVoltage / valZone, wd);\r\n            }\r\n            return result;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd)'},
#     {'method_name': 'CheckFileFormat',
#      'method_comment': '',
#      'method_code': 'publicstaticboolCheckFileFormat(Config config, int ishowChanNo){\r\n            if (config.m_DataGateList.Count <= 0 || config.m_DataGateList.Count > 10)//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n            for (int i = 0; i < config.m_DataGateList.Count; i++)\r\n            {\r\n                if (config.m_DataGateList[i].m_GateLength <= 0.01 || config.m_DataGateList[i].m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_Threshold < 0 || config.m_DataGateList[i].m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_FSFGate.m_GateIsActived)\r\n            {\r\n                if (config.m_FSFGate.m_GateLength <= 0.01 || config.m_FSFGate.m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_Threshold < 0 || config.m_FSFGate.m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_ScanNum <= 0\r\n                   || config.m_ScanNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   )//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n\r\n            if (ishowChanNo != 0)\r\n            {\r\n                return false;\r\n            }\r\n\r\n\r\n            //if (StaticParas.glConfig.m_AscanLength <= 0 )//数据格式不对\r\n            //{\r\n            //    return false;\r\n            //}\r\n\r\n            return true;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(Config config, int ishowChanNo)'},
#     {'method_name': 'ReadNewVersionData',
#      'method_comment': '',
#      'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata){\r\n            try\r\n            {\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n\r\n\r\n\r\n\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString();\r\n                string[] arrcomment = strcomment.Split(\',\');\r\n                for ( ...
#      'method_prefix': 'public static',
#      'method_param': '(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata)'},
#     {'method_name': 'ReadNewVersionData',
#      'method_comment': '',
#      'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk){\r\n            try\r\n            {\r\n                isReadOk = false;\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString() ...
#      'method_prefix': 'public static',
#      'method_param': '(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk)'},
#     {'method_name': 'GetAbsPeakValueInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleGetAbsPeakValueInGate(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP){\r\n            double temp, tempMax, tempMin;\r\n            temp = 0;\r\n            tempMax = 0;\r\n            tempMin = 0;\r\n            double thresholdFSF = FSFGate.m_Threshold;\r\n            int gateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int gateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n\r\n            // (X,Y)转换成一维\r\n\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = 0;\r\n            if ((curFSFFirstPosition + gateStartNum + gateLengthNum) > currAScanData.Length)\r\n            {\r\n                lengthNum = currAScanData.Length;\r\n            }\r\n            else\r\n            {\r\n                lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            }\r\n\r\n            for (int k = curFSFFirstPosition + gateStartNum; k < lengthNum; k++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = k;\r\n                if (currAScanData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    //temp = ((double)allData[indexOfAscan, indexOfBScan, k] - 256) * maxVoltage / 128;\r\n                    temp = ((double)currAScanData[currndex] - maxAMP) * maxVoltage / (maxAMP / 2);\r\n                    if (temp < tempMin && temp < -thresholdData)\r\n                    {\r\n                        tempMin = temp;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)currAScanData[currndex] * maxVoltage / (maxAMP / 2);\r\n                    if (temp > tempMax && temp > thresholdData)\r\n                    {\r\n                        tempMax = temp;\r\n                    }\r\n                }\r\n            }\r\n            double absMin = Math.Abs(tempMin);\r\n            if (absMin > tempMax)\r\n            {\r\n                return absMin;\r\n            }\r\n            else\r\n            {\r\n                return tempMax;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP)'},
#     {'method_name': 'FindValueInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindValueInGate(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound){\r\n            int iTOF;\r\n            bHasFound = false;\r\n            double temp = 0;\r\n\r\n            if ((curFSFFirstPosition + gateStartNum) < 0) //确保数据闸门的实际起始位置在窗口中\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum) > allData.GetLength(0) ? allData.GetLength(0) : (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            for (iTOF = curFSFFirstPosition + gateStartNum; iTOF < lengthNum; iTOF++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = iTOF;\r\n                if (allData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    temp = (8191 - (double)allData[currndex]) * maxVoltage / (maxAMP / 2);\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)allData[currndex] * maxVoltage / (maxAMP / 2);\r\n                }\r\n                if (value < 0)\r\n                {\r\n                    if (temp <= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    if (temp >= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            if (bHasFound == false)\r\n            {\r\n                iTOF = lengthNum - 1; //如果没找到符合条件的值，则返回最大时间点的下标            \r\n            }\r\n            return iTOF;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound)'},
#     {'method_name': 'CalculateFFT',
#      'method_comment': '',
#      'method_code': 'publicstaticdouble[]CalculateFFT(double[] AscanData){\r\n            //s1:求A信号中的平均值\r\n            double Avg = 0;\r\n            int AscanPoints = AscanData.Length;\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                Avg += AscanData[k];\r\n            }\r\n            Avg = Avg / AscanPoints;\r\n            //s2:去直流分量\r\n            double[] data_ascan = new double[AscanPoints];\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                data_ascan[k] = AscanData[k] - Avg;\r\n                if (data_ascan[k] > StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1)\r\n                {\r\n                    data_ascan[k] = StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1;\r\n                }\r\n                if (data_ascan[k] < -StaticParas.glRDDataCard.MAX_AMP_V / 2)\r\n                {\r\n                    data_ascan[k] = -StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n                }\r\n\r\n                data_ascan[k] /= StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n            }\r\n\r\n            double[] image = new double[data_ascan.Length];\r\n            double[] spectrum = new double[data_ascan.Length];\r\n\r\n            MathNet.Numerics.IntegralTransforms.Fourier.Forward(data_ascan, image);\r\n            int index = 0;\r\n            foreach (double re in data_ascan)\r\n            {\r\n                double im = image[index];\r\n                spectrum[index] = Math.Sqrt(re * re + im * im);\r\n                index++;\r\n            }\r\n\r\n\r\n\r\n            //  FftAlgorithm.Calculate(data_ascan); //进行FFT转换\r\n\r\n\r\n            //MaxSpectrum = spectrum.Max(); //最大频谱值\r\n            //MinSpectrum = spectrum.Min(); //最小频谱值\r\n\r\n            return spectrum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double[] AscanData)'},
#     {'method_name': 'CalclatMeanOfAScan',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalclatMeanOfAScan(int iStart, int lengthNum, byte[] AScanData){\r\n            long v = 0;\r\n            int actualLen = Math.Min(iStart + lengthNum, AScanData.Length);\r\n            for (int i = iStart; i < actualLen; i++)\r\n            {\r\n                v += AScanData[i];\r\n            }\r\n            return (v * 1.0 / actualLen);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int iStart, int lengthNum, byte[] AScanData)'},
#     {'method_name': 'DrawMeanValueImage',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidDrawMeanValueImage(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           ){\r\n\r\n               \r\n            //, int totalChannum\r\n            //, int averageValue\r\n            //, WaveDataStyle wd\r\n            //)\r\n\r\n            int m_GateLengthNum = dataGate.m_GateLengthNum;\r\n            int m_GateStartNum = dataGate.m_GateStartNum;\r\n            double m_ThresholdFSF = FSFGate.m_Threshold;\r\n            int m_GateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int m_GateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n            double m_ThresholdData = dataGate.m_Threshold;\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //for (int k = 0; k < m_IndexNum* m_ScanNum; k++)\r\n            //  int k = 0;\r\n\r\n            // Stopwatch sw = new Stopwatch();\r\n            //  sw.Start();\r\n            // System.Threading.Tasks.Parallel.ForEach(ascanData, (adata, state1) =>\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //foreach (byte[] adata in ascanData)\r\n            {\r\n                byte[] adata = ascanData[k];\r\n                //for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int i = k % m_ScanNum;\r\n                    int j = k / m_ScanNum;\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n\r\n                    if (indexofAScan > ascanData.Count - 1 || adata.Length <= 0)\r\n                    {\r\n                        m_PeakData[indexofAScan] = 0;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n                        // 取得同步闸门起点\r\n                        int curFSFFirstPosition = 0;\r\n                        if (FSFGate.m_GateIsActived)\r\n                        {\r\n                            curFSFFirstPosition = CScanPicFunction.FindFirstPostionInFSFGate(\r\n                                  FSFGate.ThreshAMP //阈值对应的正向幅值\r\n                                , FSFGate.m_GateLengthNum//同步闸门的长度\r\n                                , FSFGate.m_GateStartNum//同步闸门的开始位置,信号的下标\r\n                                , FSFGate.isPositiveThresh//正向阈值\r\n                                , adata\r\n                                , wd\r\n                                , offset\r\n                                , maxAMP\r\n                                );\r\n                        }\r\n                        //确保数据闸门的实际起始位置在窗口中\r\n                        if ((curFSFFirstPosition + m_GateStartNum) < 0)\r\n                        {\r\n                            m_GateStartNum = -curFSFFirstPosition;\r\n                        }\r\n                        int lengthNum = 0;\r\n                        if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum) > ascanData[indexofAScan].GetLength(0))\r\n                        {\r\n                            lengthNum = ascanData[indexofAScan].GetLength(0);\r\n                        }\r\n                        else\r\n                        {\r\n                            lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum;\r\n                        }\r\n                        //底波和表面波计算数据闸门的起点\r\n                        int iStart = m_GateStartNum;//只有数据闸门\r\n                        if (FSFGate.m_GateIsActived)//有同步闸门\r\n                        {\r\n         ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           )'},
#     {'method_name': 'DrawFreqDomainImage',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidDrawFreqDomainImage(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            ){\r\n\r\n\r\n            int startIndex = 0;\r\n            int endIndex = 0;\r\n\r\n            int AscanPoints = 0;\r\n            int AScanDataLen = ascanData[0].Length;\r\n\r\n            AscanPoints = dataGate.m_GateLengthNum; //需要计算的部分\r\n            startIndex = FSFGate.m_CurFSFFirstPosition + FSFGate.m_iUseBottomWave * dataGate.m_GateStartNum;\r\n            startIndex = startIndex < 0 ? 0 : startIndex;//确保数据闸门的实际起始位置在窗口中\r\n\r\n            endIndex = (startIndex//数据闸门起始位置\r\n                        + dataGate.m_GateLengthNum);//数据闸门的长度\r\n\r\n            endIndex = (endIndex) > AScanDataLen ? AScanDataLen : (endIndex);//结束下标\r\n\r\n            int dataLength = Functions.NextPower2(AscanPoints);//计算FFT的数据长度\r\n            dataLength = (int)Math.Pow(2, dataLength);//2^N\r\n            //dataLength = AscanPoints;//\r\n            int drawindex = (int)(computeFreq / displayFreq * dataLength);//获取的频幅值所在的位置\r\n            drawindex = drawindex > dataLength - 1 ? dataLength - 1 : drawindex;\r\n\r\n            double[] drawFreqAmp = new double[m_IndexNum * m_ScanNum];\r\n\r\n            double MaxAmp = double.MinValue;\r\n            double MinAmp = double.MaxValue;\r\n\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //{\r\n            //    for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n                    byte[] adata = ascanData[k];\r\n\r\n                    //int indexofAScan = j * m_ScanNum + i;\r\n                    byte[] AScanData = ascanData[indexofAScan];\r\n                    if (AScanData.Length <= 0 || AScanData.Length < AScanDataLen)\r\n                    {\r\n                        drawFreqAmp[indexofAScan] = 0;\r\n                        //return;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n\r\n\r\n                        double[] data = new double[dataLength]; //存放门限中的数据\r\n                        for (int m = startIndex; m < endIndex; m++)\r\n                        {\r\n\r\n                            data[m - startIndex] = (double)AScanData[m];\r\n                        }\r\n                        double[] spectrum = CalculateFFT(data);\r\n                        double tmpMax = spectrum.Max();\r\n                        double tmpMin = spectrum.Min();\r\n                        MaxAmp = MaxAmp < tmpMax ? tmpMax : MaxAmp;\r\n                        MinAmp = MinAmp > tmpMin ? tmpMin : MinAmp;\r\n\r\n                        drawFreqAmp[indexofAScan] = spectrum[drawindex];\r\n                    }\r\n                    //m_PeakDataInt[indexOfAScan] = (int)(drawFreqAmp[indexOfAScan] / (tmpMax - tmpMin) * (maxAMP - 1));\r\n                });\r\n            //将数据转换0-255之间的数\r\n            for (int k = 0; k < drawFreqAmp.Length; k++)\r\n            {\r\n                m_PeakData[k] = ((drawFreqAmp[k] - MinAmp) / (MaxAmp - MinAmp) * (maxAMP - 1));\r\n            }\r\n            //m_PeakData = Array.ConvertAll<double, double>(drawFreqAmp, value => (double)((value- MinAmp) * (maxAMP - 1) / (MaxAmp - MinAmp)));\r\n\r\n            FilterCScanPic(m_bmpCscan, m_PeakData, m_DrawImageStyle, colorBar, w ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            )'},
#     {'method_name': 'DrawDiffFreqDomainImage',
#      'method_comment': '',
# ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n            int gateStartNum\r\n            , int gateEndNum\r\n            , byte[] ascandata\r\n            , WaveDataStyle wd\r\n            , int offset\r\n            , int maxamp\r\n            , out byte maxPeak\r\n            , out byte minPeak\r\n            , out int maxPosition\r\n            , out int minPosition\r\n            , int step = 10\r\n            )'},
#     {'method_name': 'NumConversionTo256ForColorBar',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo256ForColorBar(double zerotoonev, short maxv){\r\n            return (int)Math.Floor(zerotoonev * maxv);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double zerotoonev, short maxv)'},
#     {'method_name': 'CalPeakData',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalPeakData(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       ){\r\n\r\n            if (ascandata == null || ascandata.Length <= 0)\r\n            {\r\n                maxIndex = 0;\r\n                return 0;\r\n            }\r\n           \r\n            //double peakdata = 0;\r\n            // 最大峰值出现位置的下标\r\n            int numMax = 0;\r\n            // 最小峰值出现位置的下标\r\n            int numMin = 0;\r\n\r\n            //double temp = 0;\r\n            double tempMax = double.MinValue;\r\n            double tempMin = double.MaxValue;\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n\r\n            int lengthNum;\r\n            if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum) > ascandata.GetLength(0))\r\n            {\r\n                lengthNum = ascandata.GetLength(0);\r\n            }\r\n            else\r\n            {\r\n                lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum;\r\n            }\r\n\r\n            byte byteMinThreshold = (byte)(NumConversionTo256(-thresholdData, wd));//- offsetToZero\r\n            byteMinThreshold = (byte)(byteMinThreshold < 1 ? 1 : byteMinThreshold);\r\n            byte byteMaxThreshold = (byte)(NumConversionTo256(thresholdData, wd));//- offsetToZero\r\n            byte byteTempMax = byte.MinValue;\r\n            byte byteTempMin = byte.MaxValue;\r\n\r\n            byte bytePeakdata = 0;\r\n\r\n            int iStart = gateStartNum;\r\n            if (FSFGate.m_GateIsActived)\r\n            {\r\n                iStart = Math.Max(curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum, 0);\r\n            }\r\n\r\n\r\n\r\n            //查找门限中的负向幅值和正向幅值及其到达下标（时间）\r\n            FindMaxPeakMinPeak(\r\n                iStart\r\n                , lengthNum\r\n                , ascandata\r\n                , wd\r\n                , offsetToZero\r\n                , maxAMP\r\n                , out byteTempMax\r\n                , out byteTempMin\r\n                , out numMax\r\n                , out numMin\r\n\r\n                );\r\n            maxIndex = numMax;\r\n            double tof = 0;\r\n            //根据不同的闸门模式，取峰值\r\n            switch (gateMode)\r\n            {\r\n                case AmplitudeMode.PostivePeak://正向峰值\r\n                    bytePeakdata = byteTempMax;\r\n                    if (bytePeakdata < byteMaxThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.NegativePeak://负向峰值\r\n                    bytePeakdata = byteTempMin;\r\n\r\n                    if (bytePeakdata > byteMinThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.PeaktoPeak://0-255,峰峰值\r\n                    bytePeakdata = (byte)(byteTempMax - byteTempMin);\r\n\r\n                    if (bytePeakdata < (byteMaxThreshold - byteMinThreshold))\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n\r\n                case AmplitudeMode.MaxPeak://最大峰值\r\n\r\n                    bytePeakdata = (byte)Math.Max(byteTempMax, maxAMP - byteTempMin);\r\n\r\n                    i ...
#      'method_prefix': 'public static',
#      'method_param': '(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       )'},
#     {'method_name': 'NumConversionTo512',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo512(double m_PeakData){\r\n            return NumConversionToData(m_PeakData, 512, WaveDataStyle.RF);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double m_PeakData)'},
#     {'method_name': 'NumConversionTo256',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo256(double m_PeakData, WaveDataStyle wd){\r\n            return NumConversionToData(m_PeakData, 256, wd);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double m_PeakData, WaveDataStyle wd)'},
#     {'method_name': 'NumConversionToData',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionToData(double value, short data, WaveDataStyle wd){\r\n            int result = 0;\r\n            if (wd == WaveDataStyle.RF)\r\n            {\r\n\r\n                if (value < -1) { value = -1; }\r\n                if (value > 1) { value = 1; }\r\n                result = (int)(Math.Floor(value * data / 2) + data / 2);\r\n            }\r\n            else\r\n            {\r\n                result = (int)(value * data);\r\n            }\r\n            return result;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double value, short data, WaveDataStyle wd)'},
#     {'method_name': 'DrawCscanOnly',
#      'method_comment': '',
#      'method_code': 'publicstaticBitmapDrawCscanOnly(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd){\r\n            for (int j = 0; j < m_IndexNum; j++)\r\n            {\r\n                for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexOfAScan = j * m_ScanNum + i;\r\n                    if (m_GateMode == AmplitudeMode.PostivePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.PeaktoPeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = (m_Data[i][ j, 0] - m_Data[i][ j, 1]) / 2 / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.NegativePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.MaxPeak)\r\n                    {\r\n                        if (m_Data[i][j, 0] > (-m_Data[i][ j, 1]))\r\n                        {\r\n                            m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                        }\r\n                        else\r\n                        {\r\n                            m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                        }\r\n                    }\r\n                    // 根据每个信号的峰值绘制图像\r\n                    //m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[i, j], maxVoltage, m_GateMode, m_DrawImageStyle));\r\n                    m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[indexOfAScan], m_DrawImageStyle, colorBar, wd));\r\n                }\r\n            }\r\n\r\n\r\n\r\n\r\n\r\n\r\n            if (m_originBitmap != null)\r\n            {\r\n                m_originBitmap.Dispose();\r\n            }\r\n            m_originBitmap = new Bitmap(m_bmpCscan, m_bmpCscan.Width, m_bmpCscan.Height);\r\n\r\n            return m_originBitmap;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd)'},
#     {'method_name': 'GetGateStartNum',
#      'method_comment': '',
#      'method_code': 'publicstaticintGetGateStartNum(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart){\r\n            if (timeStart > totalTimeLen)\r\n            {\r\n                timeStart = totalTimeLen / 2;\r\n            }\r\n            int GateStartNum = (int)(timeStart * AScanCount / totalTimeLen);\r\n            \r\n            // 如果波形开始时间 + 同步闸门开始位置 + 数据闸门开始位置 《 0\r\n            int FSFGatePosition = FSFGate.m_CurFSFFirstPosition;\r\n            if (FSFGatePosition + FSFGate.m_iUseBottomWave * GateStartNum < 0)\r\n            {\r\n                // 数据闸门开始位置 = - 同步闸门开始位置 - 波形开始时间(0)\r\n                //GateStartNum = -FSFGatePosition - displaystart;\r\n                GateStartNum = -FSFGatePosition - displaystart;\r\n                if (-1 == FSFGate.m_iUseBottomWave)//底波\r\n                {\r\n                    GateStartNum = 0;\r\n                }\r\n                else\r\n                {\r\n                    GateStartNum = FSFGatePosition;//表面波\r\n                }\r\n            }\r\n            return GateStartNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart)'},
#     {'method_name': 'GetGateLengthNum',
#      'method_comment': '',
#      'method_code': 'publicstaticintGetGateLengthNum(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum){\r\n            // 数据闸门长度 = 闸门长度 * A信号数据长度 / 采样长度\r\n            int GateLengthNum = (int)((gatelen) * AScanCount / totalTimeLen);\r\n\r\n            // 波形起始时间 +同步闸门开始位置索引 + 数据闸门开始位置 + 数据闸门长度 》 A信号数据长度\r\n            if ((displaystart + FSFGatePosition + gateStartNum + GateLengthNum) > AScanCount)\r\n            {\r\n                // 数据闸门长度 = A信号数据长度 - 同步闸门开始位置索引 - 数据闸门开始位置 - 波形起始时间\r\n                GateLengthNum = AScanCount - FSFGatePosition - gateStartNum - displaystart;\r\n            }\r\n            //存文件错误\r\n            if (GateLengthNum < 0)\r\n            {\r\n                GateLengthNum = AScanCount - gateStartNum;\r\n            }\r\n            return GateLengthNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum)'}]}],
#  'namespace_key': 'AlgorithmLib'}

# %%
namespace_dict = {}
for key in ref_dict:
    node = ref_dict[key]
    if node['namespace_key'] not in namespace_dict:
        namespace_dict[node['namespace_key']] = []
    namespace_dict[node['namespace_key']].append(node['filepath'])

# %%
for key in ref_dict:
    node = ref_dict[key]
    relocal_fpath = []
    relocal_reference_map = {}
    for k in node['source_reference']:
        k = k.removeprefix('SixLabors.')
        if k in ref_dict:
            relocal_reference_map[k] = [node['filepath']]
        if k in namespace_dict:
            relocal_reference_map[k] = namespace_dict[k]
    node['relocal_reference'] = relocal_reference_map

# %%
list(ref_dict.values())[0]
# Out:
# {'filename': 'CScanPicFunction.cs',
#  'filepath': '../data/AMC/AlgorithmLib/CScanPicFunction.cs',
#  'source_reference': ['System.Collections.Generic',
#   'System.Diagnostics',
#   'System.Drawing',
#   'System.IO',
#   'System.Linq',
#   'System.Text',
#   'System.Threading',
#   'System.Threading.Tasks',
#   'System.Windows.Forms'],
#  'source_comments': [],
#  'source_class': [{'class_name': 'CScanPicFunction',
#    'class_comment': '',
#    'class_code': '{\r\n\r\n\r\n        /// <summary>\r\n        ///  在闸门内查找第一个与波形的交叉点\r\n        /// </summary>\r\n        /// <param name="threshValue">阈值(转换为0-2^N,N是卡的位数,譬如8位卡,就是256)</param>\r\n        /// <param name="gateLengthNum">闸门长度</param>\r\n        /// <param name="gateStartNum">闸门在A信号中的起始位置</param>\r\n        /// <param name="isPositiveThresh">计算正向阈值标志,true：正向;false:负向</param>\r\n        /// <param name="ascandata">A信号数据</param>\r\n        /// <returns></returns>\r\n        public static int FindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)\r\n        {\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos +=  ...
#    'methods': [{'method_name': 'FindFirstPostionInFSFGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindFirstPostionInFSFGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n            int indexofCrossPoint = 0;\r\n            int iposMax = Math.Min(gateStartNum + gateLengthNum, ascandata.Length);\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n            //bool bInitHasFound = false;\r\n            ////粗找\r\n            //if (isPositiveThresh)//正向阈值\r\n            //{\r\n\r\n            //    for (iPos = gateStartNum; iPos < iposMax; )\r\n            //    {\r\n            //        if (ascandata[iPos] >= threshValue)\r\n            //        {\r\n            //            initIndexofCrossPoint = iPos;\r\n            //            bInitHasFound = true;\r\n            //            break;\r\n            //        }\r\n            //        iPos += step;\r\n            //        if (iPos >= iposMax && !bInitHasFound)//找到头也没有找到交点,那么缩小不长从头再来\r\n            //        {\r\n            //            Debug.WriteLine("dllzg_ggggg.....");\r\n            //            iPos = gateStartNum;\r\n            //            step--;\r\n            //            if (step == 0)\r\n            //            {\r\n            //                bInitHasFound = false;\r\n            //                bHasFound = false;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n\r\n            //    if (bInitHasFound)//如果粗找找到了交点，则进行精细查找\r\n            //    {\r\n            //        for (iPos = Math.Min(gateStartNum, initIndexofCrossPoint - step); iPos <= initIndexofCrossPoint; iPos++)\r\n            //        {\r\n            //            if (ascandata[iPos] >= threshValue)\r\n            //            {\r\n            //                indexofCrossPoint = iPos;\r\n            //                bHasFound = true;\r\n            //                break;\r\n            //            }\r\n            //        }\r\n            //    }\r\n            //}\r\n\r\n\r\n            List<byte> allamp = new List<byte>();\r\n\r\n            //int initIndexofCrossPoint = 0;//粗找的第1个交点\r\n\r\n            if (isPositiveThresh || wd != WaveDataStyle.RF) //正向阈值或者除RF以外的三种模式\r\n            {\r\n\r\n                //for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos++)\r\n                {\r\n                    byte actualamp0 = (byte)DataUtils.GetActualAmp((int)wd, ascandata[iPos], offset, maxampvalue, (float)alpha, false);\r\n                    allamp.Add(actualamp0);\r\n                    //if (wd != WaveDataStyle.RF)\r\n                    //{\r\n                    //    Console.WriteLine(actualamp0);\r\n\r\n                    //}\r\n                    if (actualamp0 >= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < iposMax; iPos += 4)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos;\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                    if ((iPos + 1) < iposMax && ascandata[iPos + 1] <= threshValue)\r\n                    {\r\n                        indexofCrossPoint = iPos + 1;\r\n                        bHasFound = true;\r\n    ...
#      'method_prefix': 'public static',
#      'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata,\r\n                                                      WaveDataStyle wd, int offset, int maxampvalue,double alpha=1.0, int step = 10)'},
#     {'method_name': 'FindFirstPostionRelativeInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindFirstPostionRelativeInGate(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata){\r\n            // 定义循环变量\r\n            int iPos = 0;\r\n            bool bHasFound = false;\r\n\r\n\r\n            if (ascandata == null)\r\n            {\r\n                return 0;\r\n            }\r\n\r\n\r\n\r\n            if (isPositiveThresh)//正向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] >= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            else//负向阈值\r\n            {\r\n                for (iPos = gateStartNum; iPos < Math.Min(gateStartNum + gateLengthNum, ascandata.Length); iPos++)\r\n                {\r\n                    if (ascandata[iPos] <= threshValue)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n\r\n            if (!bHasFound) //如果没找到符合条件的值，则返回FSF闸门0 \r\n            {\r\n                iPos = gateStartNum;//相对于起点，这是绝对位置\r\n            }\r\n            return iPos - gateStartNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int threshValue, int gateLengthNum, int gateStartNum, bool isPositiveThresh, byte[] ascandata)'},
#     {'method_name': 'CalCouplantDepth',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalCouplantDepth(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata){\r\n            int indexStartWave = FSFGate.m_GateStartNum;\r\n            //int indexSufaceWave = FSFGate.m_GateStartNum;\r\n            for (; indexStartWave < ascandata.Length; indexStartWave++)\r\n            {\r\n                if (ascandata[indexStartWave] >= FSFGate.ThreshAMP)\r\n                {\r\n                    break;\r\n                }\r\n            }\r\n            //for (; indexSufaceWave < Math.Min(FSFGate.m_GateStartNum + FSFGate.m_GateLengthNum, ascandata.Length); indexSufaceWave++)\r\n            //{\r\n            //    if (ascandata[indexSufaceWave] >= FSFGate.ThreshAMP)\r\n            //    {\r\n            //        break;\r\n            //    }\r\n\r\n            //}\r\n            return (Math.Abs(indexStartWave) * timeLen / ascandata.Length + timedelay) * v / 2;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(LockGate FSFGate, double v, double timeLen, double timedelay, byte[] ascandata)'},
#     {'method_name': 'DataToColor',
#      'method_comment': '',
#      'method_code': 'publicstaticColorDataToColor(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res);\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                else\r\n                {\r\n                    if (res < 1)\r\n                    {\r\n                        res = 1;\r\n                    }\r\n                    if (res > 511)\r\n                    {\r\n                        res = 511;\r\n                    }\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                Color colorRet = Color.FromArgb(colorBar.m_CColorData.m_ColorTab[res]);\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'DataToColorForInt',
#      'method_comment': '',
#      'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, int[] m_ColorTab, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'DataToColorForInt',
#      'method_comment': '',
#      'method_code': 'publicstaticintDataToColorForInt(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true){\r\n            int res = 0;\r\n            if (!sign)\r\n            {\r\n                res = NumConversionTo256(data, wd);\r\n            }\r\n            else\r\n            {\r\n                res = (int)data;\r\n            }\r\n\r\n            if (drawImageStyle == DrawImageStyle.Gray)\r\n            {\r\n                return Color.FromArgb(res, res, res).ToArgb();\r\n            }\r\n            else\r\n            {\r\n                res *= 2;\r\n\r\n\r\n                if (res < 0)\r\n                {\r\n                    res = 0;\r\n                }\r\n                if (res > 511)\r\n                {\r\n                    res = 511;\r\n                }\r\n\r\n                //Color colorRet = Color.FromArgb(ColorBarControlSmall.m_CColorData.m_ColorTab[res]);\r\n                int colorRet = colorBar.m_CColorData.m_ColorTab[res];\r\n                return colorRet;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double data, DrawImageStyle drawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd, bool sign = true)'},
#     {'method_name': 'OutOldColorBar',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidOutOldColorBar(){\r\n            double step = 0.25 / 63.75;\r\n            int R = 0, G = 0, B = 0;\r\n            double VoltageScope = 1.0;\r\n            for (double data = 0; data <= 1; data += step)\r\n            {\r\n\r\n                if (data <= 0)\r\n                    R = G = B = 0;\r\n                else if (data <= VoltageScope / 4)\r\n                {\r\n                    R = G = 0;\r\n                    B = Functions.RoundToInt(data * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope / 2)\r\n                {\r\n                    R = 0;\r\n                    G = Functions.RoundToInt((data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                    B = Functions.RoundToInt(255 - (data - VoltageScope / 4) * 255 * 4 / VoltageScope);\r\n                }\r\n\r\n                else if (data <= VoltageScope * 3 / 4)\r\n                {\r\n                    R = Functions.RoundToInt((data - VoltageScope / 2) * 255 * 4 / VoltageScope);\r\n                    G = 255;\r\n                    B = 0;\r\n                }\r\n\r\n                else if (data <= VoltageScope)\r\n                {\r\n                    R = 255;\r\n                    G = Functions.RoundToInt(255 - (data - VoltageScope * 3 / 4) * 255 * 4 / VoltageScope);\r\n                    B = 0;\r\n                }\r\n\r\n                else\r\n                {\r\n                    R = 255;\r\n                    G = 0;\r\n                    B = 0;\r\n                }\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '()'},
#     {'method_name': 'AdjustPeakData',
#      'method_comment': '',
#      'method_code': 'publicstaticdouble[]AdjustPeakData(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd){\r\n            int iLen = scanNum * indexNum;\r\n            double[] result = new double[iLen];\r\n            double min, max;\r\n            min = double.MaxValue;\r\n            max = double.MinValue;\r\n\r\n            for (int i = 0; i < iLen; i++) //先找到最大、最小值\r\n            {\r\n                if (data[i] > max)\r\n                {\r\n                    max = data[i];\r\n                }\r\n                if (data[i] < min)\r\n                {\r\n                    min = data[i];\r\n                }\r\n            }\r\n\r\n\r\n            double valZone = max - min;\r\n            for (int i = 0; i < iLen; i++)\r\n            {\r\n                result[i] = NumConversionTo256((data[i] - min) * m_MaxVoltage / valZone, wd);\r\n            }\r\n            return result;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double[] data, int scanNum, int indexNum, AmplitudeMode m_GateMode, double m_MaxVoltage, WaveDataStyle wd)'},
#     {'method_name': 'CheckFileFormat',
#      'method_comment': '',
#      'method_code': 'publicstaticboolCheckFileFormat(Config config, int ishowChanNo){\r\n            if (config.m_DataGateList.Count <= 0 || config.m_DataGateList.Count > 10)//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n            for (int i = 0; i < config.m_DataGateList.Count; i++)\r\n            {\r\n                if (config.m_DataGateList[i].m_GateLength <= 0.01 || config.m_DataGateList[i].m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_DataGateList[i].m_Threshold < 0 || config.m_DataGateList[i].m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_FSFGate.m_GateIsActived)\r\n            {\r\n                if (config.m_FSFGate.m_GateLength <= 0.01 || config.m_FSFGate.m_GateLength > 1000)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_GateStart < 0)\r\n                {\r\n                    return false;\r\n                }\r\n                if (config.m_FSFGate.m_Threshold < 0 || config.m_FSFGate.m_Threshold > 1)\r\n                {\r\n                    return false;\r\n                }\r\n            }\r\n            if (config.m_ScanNum <= 0\r\n                   || config.m_ScanNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   || config.m_IndexNum <= 0\r\n                   )//数据格式不对\r\n            {\r\n                return false;\r\n            }\r\n\r\n            if (ishowChanNo != 0)\r\n            {\r\n                return false;\r\n            }\r\n\r\n\r\n            //if (StaticParas.glConfig.m_AscanLength <= 0 )//数据格式不对\r\n            //{\r\n            //    return false;\r\n            //}\r\n\r\n            return true;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(Config config, int ishowChanNo)'},
#     {'method_name': 'ReadNewVersionData',
#      'method_comment': '',
#      'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata){\r\n            try\r\n            {\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n\r\n\r\n\r\n\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString();\r\n                string[] arrcomment = strcomment.Split(\',\');\r\n                for ( ...
#      'method_prefix': 'public static',
#      'method_param': '(String sFile, bool isfullshow, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata)'},
#     {'method_name': 'ReadNewVersionData',
#      'method_comment': '',
#      'method_code': 'publicstaticboolReadNewVersionData(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk){\r\n            try\r\n            {\r\n                isReadOk = false;\r\n                iShowChannelNo = 0;\r\n                config = new Config();\r\n\r\n\r\n\r\n\r\n                Stream stream = File.Open(sFile, FileMode.Open);\r\n                BinaryReader br = new BinaryReader(stream);\r\n                int version = br.ReadInt16();//内部版本号，暂时用1,表示版本1,整型\r\n                config.m_Frequency = br.ReadInt32(); //采样频率\r\n                offsetToZero = br.ReadInt32();      //偏移量\r\n                config.m_FSFGate.m_iUseBottomWave = br.ReadInt32(); //同步闸门是否底波\r\n                                                                    //StaticParas.glConfig.m_MaxVoltage = br.ReadDouble(); //电压最大值\r\n                config.m_TimeDelay = br.ReadDouble();      //延迟时间\r\n                config.m_TimeLength = br.ReadDouble();     //采样长度    \r\n                                                           //PCIe9802SImport.offsetToZero = br.ReadInt32();            //偏移量\r\n                                                           //跟踪闸门参数\r\n                config.m_FSFGate.m_GateIsActived = br.ReadBoolean();// 读取同步闸门是否启用\r\n\r\n\r\n\r\n                config.m_FSFGate.m_GateStart = br.ReadDouble();\r\n                config.m_FSFGate.m_GateLength = br.ReadDouble();\r\n                config.m_FSFGate.m_Threshold = br.ReadDouble();\r\n                if (!config.m_FSFGate.m_GateIsActived)\r\n                {\r\n                    config.m_FSFGate.m_GateStart = 0;\r\n                    config.m_FSFGate.m_GateLength = 0;\r\n                    config.m_FSFGate.m_Threshold = 0;\r\n                }\r\n\r\n                // ===================  ediy by camellia 20190815  ===========================\r\n                config.m_FullWaveFlag = br.ReadBoolean();\r\n                // 读取闸门数量\r\n                int iGateDataNum = br.ReadInt32();\r\n\r\n                for (int i = 0; i < iGateDataNum; i++)\r\n                {\r\n                    // 添加一套闸门参数\r\n                    config.m_DataGateList.Add(new LockGate());\r\n                    // 数据闸门参数\r\n                    config.m_DataGateList[i].m_GateStart = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateLength = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_Threshold = br.ReadDouble();\r\n                    config.m_DataGateList[i].m_GateMode = (AmplitudeMode)br.ReadInt32();\r\n                    // colorbar索引\r\n                    config.colorBarArray[i] = br.ReadInt32();\r\n                    // colorbar上限\r\n                    config.colorBarUpValueArray[i] = br.ReadInt32();\r\n                    // colorbar下限\r\n                    config.colorBarDownValueArray[i] = br.ReadInt32();\r\n\r\n                }\r\n\r\n                // 扫查参数\r\n                config.m_ScanWidth = br.ReadDouble();\r\n                config.m_IndexWidth = br.ReadDouble();\r\n                config.m_ScanResolution = br.ReadDouble();\r\n                config.m_IndexResolution = br.ReadDouble();\r\n\r\n\r\n                // 读入扫查行、列数\r\n                config.m_ScanNum = br.ReadInt32();\r\n                config.m_IndexNum = br.ReadInt32();\r\n\r\n                // A扫描长度\r\n                config.m_AscanLength = br.ReadInt32();\r\n                // 每个通道有多少A扫描\r\n                int OneChannelAscanNum = br.ReadInt32();\r\n                config.m_ActualCollAScanNum = (ulong)OneChannelAscanNum;\r\n                // 通道对应数（1,2,3,4,5,6,7,8）\r\n                iShowChannelNo = br.ReadInt32();\r\n                // 所有备用量\r\n                StaticParas.comments = new string[8] { "", "", "", "", "", "", "", "" };\r\n                string strcomment = br.ReadString() ...
#      'method_prefix': 'public static',
#      'method_param': '(String sFile, bool isfullshow, StatusStrip status, ToolStripStatusLabel toollabel, ref int iShowChannelNo, ref int offsetToZero, ref Config config, ref List<byte[]> oneChannelData, ref List<byte[,]> notfulldata, ref bool isReadOk)'},
#     {'method_name': 'GetAbsPeakValueInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleGetAbsPeakValueInGate(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP){\r\n            double temp, tempMax, tempMin;\r\n            temp = 0;\r\n            tempMax = 0;\r\n            tempMin = 0;\r\n            double thresholdFSF = FSFGate.m_Threshold;\r\n            int gateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int gateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n\r\n            // (X,Y)转换成一维\r\n\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = 0;\r\n            if ((curFSFFirstPosition + gateStartNum + gateLengthNum) > currAScanData.Length)\r\n            {\r\n                lengthNum = currAScanData.Length;\r\n            }\r\n            else\r\n            {\r\n                lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            }\r\n\r\n            for (int k = curFSFFirstPosition + gateStartNum; k < lengthNum; k++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = k;\r\n                if (currAScanData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    //temp = ((double)allData[indexOfAscan, indexOfBScan, k] - 256) * maxVoltage / 128;\r\n                    temp = ((double)currAScanData[currndex] - maxAMP) * maxVoltage / (maxAMP / 2);\r\n                    if (temp < tempMin && temp < -thresholdData)\r\n                    {\r\n                        tempMin = temp;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)currAScanData[currndex] * maxVoltage / (maxAMP / 2);\r\n                    if (temp > tempMax && temp > thresholdData)\r\n                    {\r\n                        tempMax = temp;\r\n                    }\r\n                }\r\n            }\r\n            double absMin = Math.Abs(tempMin);\r\n            if (absMin > tempMax)\r\n            {\r\n                return absMin;\r\n            }\r\n            else\r\n            {\r\n                return tempMax;\r\n            }\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(byte[] currAScanData, int curFSFFirstPosition, LockGate FSFGate, int gateStartNum, int gateLengthNum, double maxVoltage, double thresholdData, int maxAMP)'},
#     {'method_name': 'FindValueInGate',
#      'method_comment': '',
#      'method_code': 'publicstaticintFindValueInGate(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound){\r\n            int iTOF;\r\n            bHasFound = false;\r\n            double temp = 0;\r\n\r\n            if ((curFSFFirstPosition + gateStartNum) < 0) //确保数据闸门的实际起始位置在窗口中\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n            int lengthNum = (curFSFFirstPosition + gateStartNum + gateLengthNum) > allData.GetLength(0) ? allData.GetLength(0) : (curFSFFirstPosition + gateStartNum + gateLengthNum);\r\n            for (iTOF = curFSFFirstPosition + gateStartNum; iTOF < lengthNum; iTOF++) //查找门限中的负向幅值和正向幅值及其到达时间\r\n            {\r\n                int currndex = iTOF;\r\n                if (allData[currndex] > 8191) //此时数据值为负\r\n                {\r\n                    temp = (8191 - (double)allData[currndex]) * maxVoltage / (maxAMP / 2);\r\n                }\r\n                else\r\n                {\r\n                    temp = (double)allData[currndex] * maxVoltage / (maxAMP / 2);\r\n                }\r\n                if (value < 0)\r\n                {\r\n                    if (temp <= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n                else\r\n                {\r\n                    if (temp >= value)\r\n                    {\r\n                        bHasFound = true;\r\n                        break;\r\n                    }\r\n                }\r\n            }\r\n            if (bHasFound == false)\r\n            {\r\n                iTOF = lengthNum - 1; //如果没找到符合条件的值，则返回最大时间点的下标            \r\n            }\r\n            return iTOF;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double value, int curFSFFirstPosition, LockGate FSFGate, byte[] allData, int gateStartNum, int gateLengthNum, double maxVoltage, int maxAMP, out bool bHasFound)'},
#     {'method_name': 'CalculateFFT',
#      'method_comment': '',
#      'method_code': 'publicstaticdouble[]CalculateFFT(double[] AscanData){\r\n            //s1:求A信号中的平均值\r\n            double Avg = 0;\r\n            int AscanPoints = AscanData.Length;\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                Avg += AscanData[k];\r\n            }\r\n            Avg = Avg / AscanPoints;\r\n            //s2:去直流分量\r\n            double[] data_ascan = new double[AscanPoints];\r\n\r\n            for (int k = 0; k < AscanPoints; k++)\r\n            {\r\n                data_ascan[k] = AscanData[k] - Avg;\r\n                if (data_ascan[k] > StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1)\r\n                {\r\n                    data_ascan[k] = StaticParas.glRDDataCard.MAX_AMP_V / 2 - 1;\r\n                }\r\n                if (data_ascan[k] < -StaticParas.glRDDataCard.MAX_AMP_V / 2)\r\n                {\r\n                    data_ascan[k] = -StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n                }\r\n\r\n                data_ascan[k] /= StaticParas.glRDDataCard.MAX_AMP_V / 2;\r\n            }\r\n\r\n            double[] image = new double[data_ascan.Length];\r\n            double[] spectrum = new double[data_ascan.Length];\r\n\r\n            MathNet.Numerics.IntegralTransforms.Fourier.Forward(data_ascan, image);\r\n            int index = 0;\r\n            foreach (double re in data_ascan)\r\n            {\r\n                double im = image[index];\r\n                spectrum[index] = Math.Sqrt(re * re + im * im);\r\n                index++;\r\n            }\r\n\r\n\r\n\r\n            //  FftAlgorithm.Calculate(data_ascan); //进行FFT转换\r\n\r\n\r\n            //MaxSpectrum = spectrum.Max(); //最大频谱值\r\n            //MinSpectrum = spectrum.Min(); //最小频谱值\r\n\r\n            return spectrum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double[] AscanData)'},
#     {'method_name': 'CalclatMeanOfAScan',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalclatMeanOfAScan(int iStart, int lengthNum, byte[] AScanData){\r\n            long v = 0;\r\n            int actualLen = Math.Min(iStart + lengthNum, AScanData.Length);\r\n            for (int i = iStart; i < actualLen; i++)\r\n            {\r\n                v += AScanData[i];\r\n            }\r\n            return (v * 1.0 / actualLen);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int iStart, int lengthNum, byte[] AScanData)'},
#     {'method_name': 'DrawMeanValueImage',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidDrawMeanValueImage(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           ){\r\n\r\n               \r\n            //, int totalChannum\r\n            //, int averageValue\r\n            //, WaveDataStyle wd\r\n            //)\r\n\r\n            int m_GateLengthNum = dataGate.m_GateLengthNum;\r\n            int m_GateStartNum = dataGate.m_GateStartNum;\r\n            double m_ThresholdFSF = FSFGate.m_Threshold;\r\n            int m_GateStartNumFSF = FSFGate.m_GateStartNum;\r\n            int m_GateLengthNumFSF = FSFGate.m_GateLengthNum;\r\n            double m_ThresholdData = dataGate.m_Threshold;\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //for (int k = 0; k < m_IndexNum* m_ScanNum; k++)\r\n            //  int k = 0;\r\n\r\n            // Stopwatch sw = new Stopwatch();\r\n            //  sw.Start();\r\n            // System.Threading.Tasks.Parallel.ForEach(ascanData, (adata, state1) =>\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //foreach (byte[] adata in ascanData)\r\n            {\r\n                byte[] adata = ascanData[k];\r\n                //for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int i = k % m_ScanNum;\r\n                    int j = k / m_ScanNum;\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n\r\n                    if (indexofAScan > ascanData.Count - 1 || adata.Length <= 0)\r\n                    {\r\n                        m_PeakData[indexofAScan] = 0;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n                        // 取得同步闸门起点\r\n                        int curFSFFirstPosition = 0;\r\n                        if (FSFGate.m_GateIsActived)\r\n                        {\r\n                            curFSFFirstPosition = CScanPicFunction.FindFirstPostionInFSFGate(\r\n                                  FSFGate.ThreshAMP //阈值对应的正向幅值\r\n                                , FSFGate.m_GateLengthNum//同步闸门的长度\r\n                                , FSFGate.m_GateStartNum//同步闸门的开始位置,信号的下标\r\n                                , FSFGate.isPositiveThresh//正向阈值\r\n                                , adata\r\n                                , wd\r\n                                , offset\r\n                                , maxAMP\r\n                                );\r\n                        }\r\n                        //确保数据闸门的实际起始位置在窗口中\r\n                        if ((curFSFFirstPosition + m_GateStartNum) < 0)\r\n                        {\r\n                            m_GateStartNum = -curFSFFirstPosition;\r\n                        }\r\n                        int lengthNum = 0;\r\n                        if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum) > ascanData[indexofAScan].GetLength(0))\r\n                        {\r\n                            lengthNum = ascanData[indexofAScan].GetLength(0);\r\n                        }\r\n                        else\r\n                        {\r\n                            lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * m_GateStartNum + m_GateLengthNum;\r\n                        }\r\n                        //底波和表面波计算数据闸门的起点\r\n                        int iStart = m_GateStartNum;//只有数据闸门\r\n                        if (FSFGate.m_GateIsActived)//有同步闸门\r\n                        {\r\n         ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n             int m_IndexNum\r\n           , int m_ScanNum\r\n           , double[] m_PeakData\r\n           , LockGate FSFGate\r\n           , LockGate dataGate\r\n           , List<byte[]> ascanData\r\n           , AmplitudeMode m_GateMode\r\n           , Bitmap m_bmpCscan\r\n           , DrawImageStyle m_DrawImageStyle\r\n           , ColorBarControlSmall colorBar\r\n           , int maxAMP\r\n           , WaveDataStyle wd\r\n           , int offset\r\n           )'},
#     {'method_name': 'DrawFreqDomainImage',
#      'method_comment': '',
#      'method_code': 'publicstaticvoidDrawFreqDomainImage(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            ){\r\n\r\n\r\n            int startIndex = 0;\r\n            int endIndex = 0;\r\n\r\n            int AscanPoints = 0;\r\n            int AScanDataLen = ascanData[0].Length;\r\n\r\n            AscanPoints = dataGate.m_GateLengthNum; //需要计算的部分\r\n            startIndex = FSFGate.m_CurFSFFirstPosition + FSFGate.m_iUseBottomWave * dataGate.m_GateStartNum;\r\n            startIndex = startIndex < 0 ? 0 : startIndex;//确保数据闸门的实际起始位置在窗口中\r\n\r\n            endIndex = (startIndex//数据闸门起始位置\r\n                        + dataGate.m_GateLengthNum);//数据闸门的长度\r\n\r\n            endIndex = (endIndex) > AScanDataLen ? AScanDataLen : (endIndex);//结束下标\r\n\r\n            int dataLength = Functions.NextPower2(AscanPoints);//计算FFT的数据长度\r\n            dataLength = (int)Math.Pow(2, dataLength);//2^N\r\n            //dataLength = AscanPoints;//\r\n            int drawindex = (int)(computeFreq / displayFreq * dataLength);//获取的频幅值所在的位置\r\n            drawindex = drawindex > dataLength - 1 ? dataLength - 1 : drawindex;\r\n\r\n            double[] drawFreqAmp = new double[m_IndexNum * m_ScanNum];\r\n\r\n            double MaxAmp = double.MinValue;\r\n            double MinAmp = double.MaxValue;\r\n\r\n            Parallel.For(0, ascanData.Count, (k, loopState) =>\r\n\r\n            //for (int j = 0; j < m_IndexNum; j++)\r\n            //{\r\n            //    for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexofAScan = k;//j * m_ScanNum + i;\r\n                    byte[] adata = ascanData[k];\r\n\r\n                    //int indexofAScan = j * m_ScanNum + i;\r\n                    byte[] AScanData = ascanData[indexofAScan];\r\n                    if (AScanData.Length <= 0 || AScanData.Length < AScanDataLen)\r\n                    {\r\n                        drawFreqAmp[indexofAScan] = 0;\r\n                        //return;\r\n                        //loopState.Break();\r\n                        //loopState.Stop();\r\n                        //break;\r\n                    }\r\n                    else\r\n                    {\r\n\r\n\r\n                        double[] data = new double[dataLength]; //存放门限中的数据\r\n                        for (int m = startIndex; m < endIndex; m++)\r\n                        {\r\n\r\n                            data[m - startIndex] = (double)AScanData[m];\r\n                        }\r\n                        double[] spectrum = CalculateFFT(data);\r\n                        double tmpMax = spectrum.Max();\r\n                        double tmpMin = spectrum.Min();\r\n                        MaxAmp = MaxAmp < tmpMax ? tmpMax : MaxAmp;\r\n                        MinAmp = MinAmp > tmpMin ? tmpMin : MinAmp;\r\n\r\n                        drawFreqAmp[indexofAScan] = spectrum[drawindex];\r\n                    }\r\n                    //m_PeakDataInt[indexOfAScan] = (int)(drawFreqAmp[indexOfAScan] / (tmpMax - tmpMin) * (maxAMP - 1));\r\n                });\r\n            //将数据转换0-255之间的数\r\n            for (int k = 0; k < drawFreqAmp.Length; k++)\r\n            {\r\n                m_PeakData[k] = ((drawFreqAmp[k] - MinAmp) / (MaxAmp - MinAmp) * (maxAMP - 1));\r\n            }\r\n            //m_PeakData = Array.ConvertAll<double, double>(drawFreqAmp, value => (double)((value- MinAmp) * (maxAMP - 1) / (MaxAmp - MinAmp)));\r\n\r\n            FilterCScanPic(m_bmpCscan, m_PeakData, m_DrawImageStyle, colorBar, w ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n              int m_IndexNum\r\n            , int m_ScanNum\r\n            , double[] m_PeakData\r\n            , LockGate FSFGate\r\n            , LockGate dataGate\r\n            , List<byte[]> ascanData\r\n            , AmplitudeMode m_GateMode\r\n            , Bitmap m_bmpCscan\r\n            , DrawImageStyle m_DrawImageStyle\r\n            , ColorBarControlSmall colorBar\r\n            , double computeFreq\r\n            , double displayFreq\r\n            , int maxAMP\r\n            , WaveDataStyle wd\r\n            )'},
#     {'method_name': 'DrawDiffFreqDomainImage',
#      'method_comment': '',
# ...
#      'method_prefix': 'public static',
#      'method_param': '(\r\n            int gateStartNum\r\n            , int gateEndNum\r\n            , byte[] ascandata\r\n            , WaveDataStyle wd\r\n            , int offset\r\n            , int maxamp\r\n            , out byte maxPeak\r\n            , out byte minPeak\r\n            , out int maxPosition\r\n            , out int minPosition\r\n            , int step = 10\r\n            )'},
#     {'method_name': 'NumConversionTo256ForColorBar',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo256ForColorBar(double zerotoonev, short maxv){\r\n            return (int)Math.Floor(zerotoonev * maxv);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double zerotoonev, short maxv)'},
#     {'method_name': 'CalPeakData',
#      'method_comment': '',
#      'method_code': 'publicstaticdoubleCalPeakData(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       ){\r\n\r\n            if (ascandata == null || ascandata.Length <= 0)\r\n            {\r\n                maxIndex = 0;\r\n                return 0;\r\n            }\r\n           \r\n            //double peakdata = 0;\r\n            // 最大峰值出现位置的下标\r\n            int numMax = 0;\r\n            // 最小峰值出现位置的下标\r\n            int numMin = 0;\r\n\r\n            //double temp = 0;\r\n            double tempMax = double.MinValue;\r\n            double tempMin = double.MaxValue;\r\n\r\n            //确保数据闸门的实际起始位置在窗口中\r\n            if ((curFSFFirstPosition + gateStartNum) < 0)\r\n            {\r\n                gateStartNum = -curFSFFirstPosition;\r\n            }\r\n\r\n            int lengthNum;\r\n            if ((curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum) > ascandata.GetLength(0))\r\n            {\r\n                lengthNum = ascandata.GetLength(0);\r\n            }\r\n            else\r\n            {\r\n                lengthNum = curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum + gateLengthNum;\r\n            }\r\n\r\n            byte byteMinThreshold = (byte)(NumConversionTo256(-thresholdData, wd));//- offsetToZero\r\n            byteMinThreshold = (byte)(byteMinThreshold < 1 ? 1 : byteMinThreshold);\r\n            byte byteMaxThreshold = (byte)(NumConversionTo256(thresholdData, wd));//- offsetToZero\r\n            byte byteTempMax = byte.MinValue;\r\n            byte byteTempMin = byte.MaxValue;\r\n\r\n            byte bytePeakdata = 0;\r\n\r\n            int iStart = gateStartNum;\r\n            if (FSFGate.m_GateIsActived)\r\n            {\r\n                iStart = Math.Max(curFSFFirstPosition + FSFGate.m_iUseBottomWave * gateStartNum, 0);\r\n            }\r\n\r\n\r\n\r\n            //查找门限中的负向幅值和正向幅值及其到达下标（时间）\r\n            FindMaxPeakMinPeak(\r\n                iStart\r\n                , lengthNum\r\n                , ascandata\r\n                , wd\r\n                , offsetToZero\r\n                , maxAMP\r\n                , out byteTempMax\r\n                , out byteTempMin\r\n                , out numMax\r\n                , out numMin\r\n\r\n                );\r\n            maxIndex = numMax;\r\n            double tof = 0;\r\n            //根据不同的闸门模式，取峰值\r\n            switch (gateMode)\r\n            {\r\n                case AmplitudeMode.PostivePeak://正向峰值\r\n                    bytePeakdata = byteTempMax;\r\n                    if (bytePeakdata < byteMaxThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.NegativePeak://负向峰值\r\n                    bytePeakdata = byteTempMin;\r\n\r\n                    if (bytePeakdata > byteMinThreshold)\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n                case AmplitudeMode.PeaktoPeak://0-255,峰峰值\r\n                    bytePeakdata = (byte)(byteTempMax - byteTempMin);\r\n\r\n                    if (bytePeakdata < (byteMaxThreshold - byteMinThreshold))\r\n                    {\r\n                        bytePeakdata = 0;\r\n                    }\r\n                    break;\r\n\r\n                case AmplitudeMode.MaxPeak://最大峰值\r\n\r\n                    bytePeakdata = (byte)Math.Max(byteTempMax, maxAMP - byteTempMin);\r\n\r\n                    i ...
#      'method_prefix': 'public static',
#      'method_param': '(byte[] ascandata\r\n            , int gateStartNum\r\n            , int gateLengthNum\r\n            , AmplitudeMode gateMode\r\n            , double thresholdData\r\n            , double referencePhase\r\n            , double maxVoltage\r\n            , int curFSFFirstPosition\r\n            , LockGate FSFGate\r\n            , WaveDataStyle wd\r\n            , double currAvgAmp\r\n            , int maxAMP\r\n            , int PulseType\r\n            , int offsetToZero\r\n            , out int maxIndex\r\n       )'},
#     {'method_name': 'NumConversionTo512',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo512(double m_PeakData){\r\n            return NumConversionToData(m_PeakData, 512, WaveDataStyle.RF);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double m_PeakData)'},
#     {'method_name': 'NumConversionTo256',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionTo256(double m_PeakData, WaveDataStyle wd){\r\n            return NumConversionToData(m_PeakData, 256, wd);\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double m_PeakData, WaveDataStyle wd)'},
#     {'method_name': 'NumConversionToData',
#      'method_comment': '',
#      'method_code': 'publicstaticintNumConversionToData(double value, short data, WaveDataStyle wd){\r\n            int result = 0;\r\n            if (wd == WaveDataStyle.RF)\r\n            {\r\n\r\n                if (value < -1) { value = -1; }\r\n                if (value > 1) { value = 1; }\r\n                result = (int)(Math.Floor(value * data / 2) + data / 2);\r\n            }\r\n            else\r\n            {\r\n                result = (int)(value * data);\r\n            }\r\n            return result;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double value, short data, WaveDataStyle wd)'},
#     {'method_name': 'DrawCscanOnly',
#      'method_comment': '',
#      'method_code': 'publicstaticBitmapDrawCscanOnly(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd){\r\n            for (int j = 0; j < m_IndexNum; j++)\r\n            {\r\n                for (int i = 0; i < m_ScanNum; i++)\r\n                {\r\n                    int indexOfAScan = j * m_ScanNum + i;\r\n                    if (m_GateMode == AmplitudeMode.PostivePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.PeaktoPeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = (m_Data[i][ j, 0] - m_Data[i][ j, 1]) / 2 / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.NegativePeak)\r\n                    {\r\n                        m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                    }\r\n                    else if (m_GateMode == AmplitudeMode.MaxPeak)\r\n                    {\r\n                        if (m_Data[i][j, 0] > (-m_Data[i][ j, 1]))\r\n                        {\r\n                            m_PeakData[indexOfAScan] = m_Data[i][ j, 0] / 32768 * maxVoltage;\r\n                        }\r\n                        else\r\n                        {\r\n                            m_PeakData[indexOfAScan] = -m_Data[i][ j, 1] / 32768 * maxVoltage;\r\n                        }\r\n                    }\r\n                    // 根据每个信号的峰值绘制图像\r\n                    //m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[i, j], maxVoltage, m_GateMode, m_DrawImageStyle));\r\n                    m_bmpCscan.SetPixel(i, j, DataToColor(m_PeakData[indexOfAScan], m_DrawImageStyle, colorBar, wd));\r\n                }\r\n            }\r\n\r\n\r\n\r\n\r\n\r\n\r\n            if (m_originBitmap != null)\r\n            {\r\n                m_originBitmap.Dispose();\r\n            }\r\n            m_originBitmap = new Bitmap(m_bmpCscan, m_bmpCscan.Width, m_bmpCscan.Height);\r\n\r\n            return m_originBitmap;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(int m_IndexNum, int m_ScanNum, AmplitudeMode m_GateMode, double[] m_PeakData, List<byte[,]> m_Data, Bitmap m_bmpCscan, double maxVoltage, Bitmap m_originBitmap, DrawImageStyle m_DrawImageStyle, ColorBarControlSmall colorBar, WaveDataStyle wd)'},
#     {'method_name': 'GetGateStartNum',
#      'method_comment': '',
#      'method_code': 'publicstaticintGetGateStartNum(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart){\r\n            if (timeStart > totalTimeLen)\r\n            {\r\n                timeStart = totalTimeLen / 2;\r\n            }\r\n            int GateStartNum = (int)(timeStart * AScanCount / totalTimeLen);\r\n            \r\n            // 如果波形开始时间 + 同步闸门开始位置 + 数据闸门开始位置 《 0\r\n            int FSFGatePosition = FSFGate.m_CurFSFFirstPosition;\r\n            if (FSFGatePosition + FSFGate.m_iUseBottomWave * GateStartNum < 0)\r\n            {\r\n                // 数据闸门开始位置 = - 同步闸门开始位置 - 波形开始时间(0)\r\n                //GateStartNum = -FSFGatePosition - displaystart;\r\n                GateStartNum = -FSFGatePosition - displaystart;\r\n                if (-1 == FSFGate.m_iUseBottomWave)//底波\r\n                {\r\n                    GateStartNum = 0;\r\n                }\r\n                else\r\n                {\r\n                    GateStartNum = FSFGatePosition;//表面波\r\n                }\r\n            }\r\n            return GateStartNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double timeStart, double totalTimeLen, int AScanCount, LockGate FSFGate, int displaystart)'},
#     {'method_name': 'GetGateLengthNum',
#      'method_comment': '',
#      'method_code': 'publicstaticintGetGateLengthNum(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum){\r\n            // 数据闸门长度 = 闸门长度 * A信号数据长度 / 采样长度\r\n            int GateLengthNum = (int)((gatelen) * AScanCount / totalTimeLen);\r\n\r\n            // 波形起始时间 +同步闸门开始位置索引 + 数据闸门开始位置 + 数据闸门长度 》 A信号数据长度\r\n            if ((displaystart + FSFGatePosition + gateStartNum + GateLengthNum) > AScanCount)\r\n            {\r\n                // 数据闸门长度 = A信号数据长度 - 同步闸门开始位置索引 - 数据闸门开始位置 - 波形起始时间\r\n                GateLengthNum = AScanCount - FSFGatePosition - gateStartNum - displaystart;\r\n            }\r\n            //存文件错误\r\n            if (GateLengthNum < 0)\r\n            {\r\n                GateLengthNum = AScanCount - gateStartNum;\r\n            }\r\n            return GateLengthNum;\r\n        }',
#      'method_prefix': 'public static',
#      'method_param': '(double gatelen, double totalTimeLen, int AScanCount, int FSFGatePosition, int displaystart, int gateStartNum)'}]}],
#  'namespace_key': 'AlgorithmLib',
#  'relocal_reference': {}}

# %%
cs_files
# Out:
# ['../data/AMC/AlgorithmLib/CScanPicFunction.cs',
#  '../data/AMC/AlgorithmLib/CScanPicFunctionGPU - 副本 (2).cs',
#  '../data/AMC/AlgorithmLib/CScanPicFunctionGPU - 副本.cs',
#  '../data/AMC/AlgorithmLib/CScanPicFunctionGPU.cs',
#  '../data/AMC/AlgorithmLib/UltrasonicalPeakDll.cs',
#  '../data/AMC/AlgorithmLib/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AlgorithmLib/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AlgorithmLib/Properties/AssemblyInfo.cs',
#  '../data/AMC/AlgorithmLib/Properties/Resources.Designer.cs',
#  '../data/AMC/AlgorithmLib/Properties/Settings.Designer.cs',
#  '../data/AMC/AMC/About.cs',
#  '../data/AMC/AMC/About.Designer.cs',
#  '../data/AMC/AMC/AreaEdit.cs',
#  '../data/AMC/AMC/AreaEdit.designer.cs',
#  '../data/AMC/AMC/AsResult.cs',
#  '../data/AMC/AMC/AsResult.Designer.cs',
#  '../data/AMC/AMC/BScanImageForm.cs',
#  '../data/AMC/AMC/BScanImageForm.Designer.cs',
#  '../data/AMC/AMC/CheckUserFrm.cs',
#  '../data/AMC/AMC/CheckUserFrm.Designer.cs',
#  '../data/AMC/AMC/CScanPic.cs',
#  '../data/AMC/AMC/CScanPic.Designer.cs',
#  '../data/AMC/AMC/ExternalIterface.cs',
#  '../data/AMC/AMC/FftForm.cs',
#  '../data/AMC/AMC/FftForm.Designer.cs',
#  '../data/AMC/AMC/Form1.cs',
#  '../data/AMC/AMC/Form1.Designer.cs',
#  '../data/AMC/AMC/Form1_AutoScan.Designer.cs',
#  '../data/AMC/AMC/Form1_DataManager.Designer.cs',
#  '../data/AMC/AMC/Form1_DataProcess.Designer.cs',
#  '../data/AMC/AMC/Form1_Gail.Designer.cs',
#  '../data/AMC/AMC/Form1_Task.Designer.cs',
#  '../data/AMC/AMC/Form1_Test.Designer.cs',
#  '../data/AMC/AMC/FreqPara.cs',
#  '../data/AMC/AMC/FreqPara.Designer.cs',
#  '../data/AMC/AMC/frmMark.cs',
#  '../data/AMC/AMC/frmMark.Designer.cs',
#  '../data/AMC/AMC/frmRemarkList.cs',
#  '../data/AMC/AMC/frmRemarkList.Designer.cs',
#  '../data/AMC/AMC/JSRControlForm.cs',
#  '../data/AMC/AMC/JSRControlForm.Designer.cs',
#  '../data/AMC/AMC/LayoutControl1.cs',
#  '../data/AMC/AMC/LayoutControl1.designer.cs',
#  '../data/AMC/AMC/LayoutSet.cs',
#  '../data/AMC/AMC/LayoutSet.designer.cs',
#  '../data/AMC/AMC/LoadingForm.cs',
#  '../data/AMC/AMC/LoadingForm.Designer.cs',
#  '../data/AMC/AMC/LoadingHelper.cs',
#  '../data/AMC/AMC/LoginForm.cs',
#  '../data/AMC/AMC/LoginForm.designer.cs',
#  '../data/AMC/AMC/MeasurePareFrm.cs',
#  '../data/AMC/AMC/MeasurePareFrm.Designer.cs',
#  '../data/AMC/AMC/MeasureVzForm.cs',
#  '../data/AMC/AMC/MeasureVzForm.Designer.cs',
#  '../data/AMC/AMC/MyAscan.cs',
#  '../data/AMC/AMC/MyAscan.Designer.cs',
#  '../data/AMC/AMC/MyAscanOffline.cs',
#  '../data/AMC/AMC/MyAscanOffline.Designer.cs',
#  '../data/AMC/AMC/OfflineCScanPic.cs',
#  '../data/AMC/AMC/OfflineCScanPic.Designer.cs',
#  '../data/AMC/AMC/OutlookSettingForm.cs',
#  '../data/AMC/AMC/OutlookSettingForm.Designer.cs',
#  '../data/AMC/AMC/Program.cs',
#  '../data/AMC/AMC/Resource1.Designer.cs',
#  '../data/AMC/AMC/SecondFrm.cs',
#  '../data/AMC/AMC/SecondFrm.Designer.cs',
#  '../data/AMC/AMC/SelectImgStyle.cs',
#  '../data/AMC/AMC/SelectImgStyle.Designer.cs',
#  '../data/AMC/AMC/SelfDefineImgSizeFrm.cs',
#  '../data/AMC/AMC/SelfDefineImgSizeFrm.Designer.cs',
#  '../data/AMC/AMC/SuspendForm.cs',
#  '../data/AMC/AMC/SuspendForm.Designer.cs',
#  '../data/AMC/AMC/UMSpdf.cs',
#  '../data/AMC/AMC/UMSpdf.Designer.cs',
#  '../data/AMC/AMC/UserControlRegion.cs',
#  '../data/AMC/AMC/UserControlRegion.designer.cs',
#  '../data/AMC/AMC/WaitForm1.cs',
#  '../data/AMC/AMC/WaitForm1.designer.cs',
#  '../data/AMC/AMC/WaveOffsetForm.cs',
#  '../data/AMC/AMC/WaveOffsetForm.Designer.cs',
#  '../data/AMC/AMC/WaveSetting.cs',
#  '../data/AMC/AMC/WorkPartSet.cs',
#  '../data/AMC/AMC/WorkPartSet.designer.cs',
#  '../data/AMC/AMC/WorkpieceStatus.cs',
#  '../data/AMC/AMC/WorkpieceStatus.Designer.cs',
#  '../data/AMC/AMC/AutoScan/AbstractAutoScanTask.cs',
#  '../data/AMC/AMC/AutoScan/AutoScanLog.cs',
#  '../data/AMC/AMC/AutoScan/AutoScanParallelTask.cs',
#  '../data/AMC/AMC/AutoScan/AutoScanSerialTask.cs',
#  '../data/AMC/AMC/AutoScan/PlcCommand.cs',
#  '../data/AMC/AMC/AutoScan/PointXYZ.cs',
#  '../data/AMC/AMC/AutoScan/RobotStatus.cs',
#  '../data/AMC/AMC/AutoScan/UI_MonitorIO.cs',
#  '../data/AMC/AMC/AutoScan/UI_MonitorIO.designer.cs',
#  '../data/AMC/AMC/AutoScan/WorkPieceAuto.cs',
#  '../data/AMC/AMC/DM/AdaptFont.cs',
#  '../data/AMC/AMC/DM/AuthorityControl.cs',
#  '../data/AMC/AMC/DM/EnumClass.cs',
#  '../data/AMC/AMC/DM/Form_Acc.cs',
#  '../data/AMC/AMC/DM/Form_Acc.designer.cs',
#  '../data/AMC/AMC/DM/Form_Acc_Add.cs',
#  '../data/AMC/AMC/DM/Form_Acc_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Acc_Check.cs',
#  '../data/AMC/AMC/DM/Form_Acc_Check.designer.cs',
#  '../data/AMC/AMC/DM/Form_Axises.cs',
#  '../data/AMC/AMC/DM/Form_Axises.designer.cs',
#  '../data/AMC/AMC/DM/Form_Axises_Add.cs',
#  '../data/AMC/AMC/DM/Form_Axises_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Cells_Edit.cs',
#  '../data/AMC/AMC/DM/Form_Cells_Edit.designer.cs',
#  '../data/AMC/AMC/DM/Form_Couplants.cs',
#  '../data/AMC/AMC/DM/Form_Couplants.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Couplants_Add.cs',
#  '../data/AMC/AMC/DM/Form_Couplants_Add.Designer.cs',
#  '../data/AMC/AMC/DM/Form_DeviceApps.cs',
#  '../data/AMC/AMC/DM/Form_DeviceApps.Designer.cs',
#  '../data/AMC/AMC/DM/Form_DeviceApps_Add.cs',
#  '../data/AMC/AMC/DM/Form_DeviceApps_Add.Designer.cs',
#  '../data/AMC/AMC/DM/Form_DeviceEntities.cs',
#  '../data/AMC/AMC/DM/Form_DeviceEntities.Designer.cs',
#  '../data/AMC/AMC/DM/Form_DeviceEntities_Add.cs',
#  '../data/AMC/AMC/DM/Form_DeviceEntities_Add.Designer.cs',
#  '../data/AMC/AMC/DM/Form_ExceptionHandling.cs',
#  '../data/AMC/AMC/DM/Form_ExceptionHandling.designer.cs',
#  '../data/AMC/AMC/DM/Form_Globalpars.cs',
#  '../data/AMC/AMC/DM/Form_Globalpars.designer.cs',
#  '../data/AMC/AMC/DM/Form_Globalpars_Add.cs',
#  '../data/AMC/AMC/DM/Form_Globalpars_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_IOInfo.cs',
#  '../data/AMC/AMC/DM/Form_IOInfo.designer.cs',
#  '../data/AMC/AMC/DM/Form_IOInfo_Add.cs',
#  '../data/AMC/AMC/DM/Form_IOInfo_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_KeyParameters.cs',
#  '../data/AMC/AMC/DM/Form_KeyParameters.designer.cs',
#  '../data/AMC/AMC/DM/Form_KeyParameters_Add.cs',
#  '../data/AMC/AMC/DM/Form_KeyParameters_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_LayControls.cs',
#  '../data/AMC/AMC/DM/Form_LayControls.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Layouts.cs',
#  '../data/AMC/AMC/DM/Form_Layouts.designer.cs',
#  '../data/AMC/AMC/DM/Form_Layouts_Add.cs',
#  '../data/AMC/AMC/DM/Form_Layouts_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_LogConfigs.cs',
#  '../data/AMC/AMC/DM/Form_LogConfigs.designer.cs',
#  '../data/AMC/AMC/DM/Form_LogConfigs_Add.cs',
#  '../data/AMC/AMC/DM/Form_LogConfigs_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Materials.cs',
#  '../data/AMC/AMC/DM/Form_Materials.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Materials_Add.cs',
#  '../data/AMC/AMC/DM/Form_Materials_Add.Designer.cs',
#  '../data/AMC/AMC/DM/Form_MeasureThick.cs',
#  '../data/AMC/AMC/DM/Form_MeasureThick.designer.cs',
#  '../data/AMC/AMC/DM/Form_Modules.cs',
#  '../data/AMC/AMC/DM/Form_Modules.designer.cs',
#  '../data/AMC/AMC/DM/Form_Modules_Add.cs',
#  '../data/AMC/AMC/DM/Form_Modules_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_MonitorParas.cs',
#  '../data/AMC/AMC/DM/Form_MonitorParas.designer.cs',
#  '../data/AMC/AMC/DM/Form_Productlines.cs',
#  '../data/AMC/AMC/DM/Form_Productlines.designer.cs',
#  '../data/AMC/AMC/DM/Form_Productlines_Add.cs',
#  '../data/AMC/AMC/DM/Form_Productlines_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Products.cs',
#  '../data/AMC/AMC/DM/Form_Products.designer.cs',
#  '../data/AMC/AMC/DM/Form_Products_Add.cs',
#  '../data/AMC/AMC/DM/Form_Products_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_RobotTest.cs',
#  '../data/AMC/AMC/DM/Form_RobotTest.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Roles.cs',
#  '../data/AMC/AMC/DM/Form_Roles.designer.cs',
#  '../data/AMC/AMC/DM/Form_Roles_Add.cs',
#  '../data/AMC/AMC/DM/Form_Roles_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Role_Auth.cs',
#  '../data/AMC/AMC/DM/Form_Role_Auth.designer.cs',
#  '../data/AMC/AMC/DM/Form_Scanareas.cs',
#  '../data/AMC/AMC/DM/Form_Scanareas.designer.cs',
#  '../data/AMC/AMC/DM/Form_Scanareas_Add.cs',
#  '../data/AMC/AMC/DM/Form_Scanareas_Add.designer.cs',
#  '../data/AMC/AMC/DM/Form_Traj.cs',
#  '../data/AMC/AMC/DM/Form_Traj.Designer.cs',
#  '../data/AMC/AMC/DM/Form_TrajAxis.cs',
#  '../data/AMC/AMC/DM/Form_TrajAxis.Designer.cs',
#  '../data/AMC/AMC/DM/Form_TrajAxises.cs',
#  '../data/AMC/AMC/DM/Form_TrajAxises.Designer.cs',
#  '../data/AMC/AMC/DM/Form_TrajPoints.cs',
#  '../data/AMC/AMC/DM/Form_TrajPoints.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Traj_Add.cs',
#  '../data/AMC/AMC/DM/Form_Traj_Add.Designer.cs',
#  '../data/AMC/AMC/DM/Form_Users.cs',
#  '../data/AMC/AMC/DM/Form_Users.designer.cs',
#  '../data/AMC/AMC/DM/Form_Users_Add.cs',
#  '../data/AMC/AMC/DM/Form_Users_Add.designer.cs',
#  '../data/AMC/AMC/DM/TrajAxisUI.cs',
#  '../data/AMC/AMC/DM/TrajAxisUI.Designer.cs',
#  '../data/AMC/AMC/LayControl/LeftRightAxis.cs',
#  '../data/AMC/AMC/LayControl/LeftRightAxis.Designer.cs',
#  '../data/AMC/AMC/LayControl/MontionCardUI.cs',
#  '../data/AMC/AMC/LayControl/MontionCardUI.Designer.cs',
#  '../data/AMC/AMC/LayControl/UpDownAxis.cs',
#  '../data/AMC/AMC/LayControl/UpDownAxis.Designer.cs',
#  '../data/AMC/AMC/MultiArea/OneScanArea.cs',
#  '../data/AMC/AMC/MultiArea/OneWorkPart.cs',
#  '../data/AMC/AMC/MultiArea/ScanLayoutInfo.cs',
#  '../data/AMC/AMC/MultiArea/ScanLayoutSetting.cs',
#  '../data/AMC/AMC/MultiArea/WorkParts.cs',
#  '../data/AMC/AMC/MultiAreaXml/SerializeScanLayoutXml.cs',
#  '../data/AMC/AMC/MultiAreaXml/SerializeWorkPartsXml.cs',
#  '../data/AMC/AMC/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/AMC/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/AMC/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/AMC/Properties/AssemblyInfo.cs',
#  '../data/AMC/AMC/Properties/Resources.Designer.cs',
#  '../data/AMC/AMC/Properties/Settings.Designer.cs',
#  '../data/AMC/AMC/SystemPara/Form_GlobalparaDataType.cs',
#  '../data/AMC/AMC/SystemPara/Form_GlobalparaDataType.Designer.cs',
#  '../data/AMC/AMC/SystemPara/GlobalParameter.cs',
#  '../data/AMC/AMC/SystemPara/GlobalParameter.Designer.cs',
#  '../data/AMC/AMC/SystemPara/SystemParameter.cs',
#  '../data/AMC/AMC/WorkPiece/UserControlWorkPiece.cs',
#  '../data/AMC/AMC/WorkPiece/UserControlWorkPiece.Designer.cs',
#  '../data/AMC/AMC/WorkPiece/UserControlWorkPieceStation.cs',
#  '../data/AMC/AMC/WorkPiece/UserControlWorkPieceStation.Designer.cs',
#  '../data/AMC/AMC/WorkPiece/WorkPiece.cs',
#  '../data/AMC/Common/DataCollectCard.cs',
#  '../data/AMC/Common/gclib-bak.cs',
#  '../data/AMC/Common/gclib.cs',
#  '../data/AMC/Common/JSRPulseDll.cs',
#  '../data/AMC/Common/JSRPulser.cs',
#  '../data/AMC/Common/MotionAxis.cs',
#  '../data/AMC/Common/MotionAxisUsingDll.cs',
#  '../data/AMC/Common/PCIe9802Import.cs',
#  '../data/AMC/Common/PCIe9802SImport.cs',
#  '../data/AMC/Common/WorkPiece.cs',
#  '../data/AMC/Common/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Common/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Common/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Common/Properties/AssemblyInfo.cs',
#  '../data/AMC/DatacardLib/AbstractDataCard.cs',
#  '../data/AMC/DatacardLib/RDConvertType.cs',
#  '../data/AMC/DatacardLib/RDDataCardEnums.cs',
#  '../data/AMC/DatacardLib/RDDataCardParameters.cs',
#  '../data/AMC/DatacardLib/RDDataType.cs',
#  '../data/AMC/DatacardLib/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DatacardLib/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DatacardLib/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DatacardLib/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DatacardLib/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DatacardLib/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DatacardLib/PCIE4619/ImportPCIe4619.cs',
#  '../data/AMC/DatacardLib/PCIE9802/ImportPCIe9802.cs',
#  '../data/AMC/DatacardLib/PCIE9802/PCIE9802_Enum.cs',
#  '../data/AMC/DatacardLib/PCIE9802S/ImportPCIe9802S.cs',
#  '../data/AMC/DatacardLib/Properties/AssemblyInfo.cs',
#  '../data/AMC/DatacardLib/USS8802/ImportUSS8802.cs',
#  '../data/AMC/Devices/AbstractDevice.cs',
#  '../data/AMC/Devices/PointXYZ.cs',
#  '../data/AMC/Devices/PulserType.cs',
#  '../data/AMC/Devices/DeviceException/DeviceException.cs',
#  '../data/AMC/Devices/IO/AbstractIO.cs',
#  '../data/AMC/Devices/IO/GailIO/GailIO.cs',
#  '../data/AMC/Devices/IO/SiemensIO/SiemensIO.cs',
#  '../data/AMC/Devices/MeasureThickDevice/GlueMeasurePara.cs',
#  '../data/AMC/Devices/MeasureThickDevice/MeasureThickDeivce.cs',
#  '../data/AMC/Devices/MotionCard/AbstractMotionCard.cs',
#  '../data/AMC/Devices/MotionCard/ExtAxises.cs',
#  '../data/AMC/Devices/MotionCard/MotionAxises.cs',
#  '../data/AMC/Devices/MotionCard/MultiAxisPara.cs',
#  '../data/AMC/Devices/MotionCard/GailMotionCard/GailMotionCard.cs',
#  '../data/AMC/Devices/MotionCard/GailMotionCard/gclib.cs',
#  '../data/AMC/Devices/MotionCard/RobotMotionCard/AxisArgo.cs',
#  '../data/AMC/Devices/MotionCard/RobotMotionCard/ConstValue.cs',
#  '../data/AMC/Devices/MotionCard/RobotMotionCard/MatrixClass.cs',
#  '../data/AMC/Devices/MotionCard/RobotMotionCard/RobotMotionCard - 副本_0423.cs',
#  '../data/AMC/Devices/MotionCard/RobotMotionCard/RobotMotionCard.cs',
#  '../data/AMC/Devices/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Devices/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Devices/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Devices/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Devices/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Devices/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Devices/Properties/AssemblyInfo.cs',
#  '../data/AMC/Devices/ScancodeGun/AbstractScanCode.cs',
#  '../data/AMC/Devices/ScancodeGun/KeyenceScanCode.cs',
#  '../data/AMC/Devices/ScancodeGun/ScanHomeScanCode.cs',
#  '../data/AMC/DM/Pair.cs',
#  '../data/AMC/DM/SqliteTableName.cs',
#  '../data/AMC/DM/dao/AccessoriesDao.cs',
#  '../data/AMC/DM/dao/AxisesDao.cs',
#  '../data/AMC/DM/dao/BaseDao.cs',
#  '../data/AMC/DM/dao/CellsDao.cs',
#  '../data/AMC/DM/dao/CommonDao.cs',
#  '../data/AMC/DM/dao/CouplantsDao.cs',
#  '../data/AMC/DM/dao/DeviceAppsDao.cs',
#  '../data/AMC/DM/dao/DeviceEntitiesDao.cs',
#  '../data/AMC/DM/dao/GlobalparsDao.cs',
#  '../data/AMC/DM/dao/IncludeInQueryAttribute.cs',
#  '../data/AMC/DM/dao/IOInfosDao.cs',
#  '../data/AMC/DM/dao/KeyParametersDao.cs',
#  '../data/AMC/DM/dao/LayControlsDao.cs',
#  '../data/AMC/DM/dao/LayoutsDao.cs',
#  '../data/AMC/DM/dao/LogConfigsDao.cs',
#  '../data/AMC/DM/dao/MaterialsDao.cs',
#  '../data/AMC/DM/dao/ModulesDao.cs',
#  '../data/AMC/DM/dao/MotionTrajsDao.cs',
#  '../data/AMC/DM/dao/ProductlinesDao.cs',
#  '../data/AMC/DM/dao/ProductsDao.cs',
#  '../data/AMC/DM/dao/RolesDao.cs',
#  '../data/AMC/DM/dao/ScanareasDao.cs',
#  '../data/AMC/DM/dao/SQLiteBaseDao.cs',
#  '../data/AMC/DM/dao/SQLiteConnectionPool.cs',
#  '../data/AMC/DM/dao/TrajAxisesDao.cs',
#  '../data/AMC/DM/dao/TrajPointsDao.cs',
#  '../data/AMC/DM/dao/UsersDao.cs',
#  '../data/AMC/DM/entity/AbstractSQLiteEntity.cs',
#  '../data/AMC/DM/entity/Accessories.cs',
#  '../data/AMC/DM/entity/Axises.cs',
#  '../data/AMC/DM/entity/Cells.cs',
#  '../data/AMC/DM/entity/Couplants.cs',
#  '../data/AMC/DM/entity/DeviceApps.cs',
#  '../data/AMC/DM/entity/DeviceEntities.cs',
#  '../data/AMC/DM/entity/Globalpars.cs',
#  '../data/AMC/DM/entity/IOInfos.cs',
#  '../data/AMC/DM/entity/KeyParameters.cs',
#  '../data/AMC/DM/entity/LayControls.cs',
#  '../data/AMC/DM/entity/Layouts.cs',
#  '../data/AMC/DM/entity/LogConfigs.cs',
#  '../data/AMC/DM/entity/Materials.cs',
#  '../data/AMC/DM/entity/Modules.cs',
#  '../data/AMC/DM/entity/MotionAxis.cs',
#  '../data/AMC/DM/entity/MotionTrajs.cs',
#  '../data/AMC/DM/entity/Productlines.cs',
#  '../data/AMC/DM/entity/Products.cs',
#  '../data/AMC/DM/entity/RelationTrajAndTrajPoint.cs',
#  '../data/AMC/DM/entity/Roles.cs',
#  '../data/AMC/DM/entity/Scanareas.cs',
#  '../data/AMC/DM/entity/TrajAxises.cs',
#  '../data/AMC/DM/entity/TrajPoints.cs',
#  '../data/AMC/DM/entity/Users.cs',
#  '../data/AMC/DM/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DM/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DM/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DM/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/DM/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/DM/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/DM/Properties/AssemblyInfo.cs',
#  '../data/AMC/DM/service/AccessoriesService.cs',
#  '../data/AMC/DM/service/AxisesService.cs',
#  '../data/AMC/DM/service/CellsService.cs',
#  '../data/AMC/DM/service/CommonService.cs',
#  '../data/AMC/DM/service/CouplantsService.cs',
#  '../data/AMC/DM/service/DeviceAppsService.cs',
#  '../data/AMC/DM/service/DeviceEntitiesService.cs',
#  '../data/AMC/DM/service/GlobalparsService.cs',
#  '../data/AMC/DM/service/IOInfosService.cs',
#  '../data/AMC/DM/service/ISqliteService.cs',
#  '../data/AMC/DM/service/KeyParametersService.cs',
#  '../data/AMC/DM/service/LayControlsService.cs',
#  '../data/AMC/DM/service/LayoutsService.cs',
#  '../data/AMC/DM/service/LogConfigService.cs',
#  '../data/AMC/DM/service/MaterialsService.cs',
#  '../data/AMC/DM/service/ModulesService.cs',
#  '../data/AMC/DM/service/MotionTrajsService.cs',
#  '../data/AMC/DM/service/ProductlinesService.cs',
#  '../data/AMC/DM/service/ProductsService.cs',
#  '../data/AMC/DM/service/RolesService.cs',
#  '../data/AMC/DM/service/ScanareasService.cs',
#  '../data/AMC/DM/service/TrajAxisesService.cs',
#  '../data/AMC/DM/service/TrajPointsService.cs',
#  '../data/AMC/DM/service/UsersService.cs',
#  '../data/AMC/DM/service/impl/AccessoriesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/AxisesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/CellsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/CommonServiceImpl.cs',
#  '../data/AMC/DM/service/impl/CouplantsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/DeviceAppsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/DeviceEntitiesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/GlobalparsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/IOInfosServiceImpl.cs',
#  '../data/AMC/DM/service/impl/KeyParametersServiceImpl.cs',
#  '../data/AMC/DM/service/impl/LayControlsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/LayoutsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/LogConfigServiceImpl.cs',
#  '../data/AMC/DM/service/impl/MaterialsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/ModulesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/MotionTrajsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/ProductlinesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/ProductsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/RolesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/ScanareasServiceImpl.cs',
#  '../data/AMC/DM/service/impl/SqliteServiceImpl.cs',
#  '../data/AMC/DM/service/impl/TrajAxisesServiceImpl.cs',
#  '../data/AMC/DM/service/impl/TrajPointsServiceImpl.cs',
#  '../data/AMC/DM/service/impl/UsersServiceImpl.cs',
#  '../data/AMC/GitId/Link.cs',
#  '../data/AMC/GitId/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/GitId/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/GitId/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/GitId/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/GitId/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/GitId/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/GitId/Properties/AssemblyInfo.cs',
#  '../data/AMC/Global/AppConfig.cs',
#  '../data/AMC/Global/Config.cs',
#  '../data/AMC/Global/DatatypeDefine.cs',
#  '../data/AMC/Global/FreqInfo.cs',
#  '../data/AMC/Global/Global.cs',
#  '../data/AMC/Global/IntPtrType.cs',
#  '../data/AMC/Global/JSRParas.cs',
#  '../data/AMC/Global/LockGate.cs',
#  '../data/AMC/Global/Message.cs',
#  '../data/AMC/Global/MyBackPanel.cs',
#  '../data/AMC/Global/MyPanelGroup.cs',
#  '../data/AMC/Global/MyTablePage.cs',
#  '../data/AMC/Global/OutLineShareParamters.cs',
#  '../data/AMC/Global/ReadDataType.cs',
#  '../data/AMC/Global/RubberLine.cs',
#  '../data/AMC/Global/WorkPartComboxItem.cs',
#  '../data/AMC/Global/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Global/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Global/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Global/Properties/AssemblyInfo.cs',
#  '../data/AMC/Measure/AbsGeomController.cs',
#  '../data/AMC/Measure/GeomDrawRegion.cs',
#  '../data/AMC/Measure/GeomDrawRegion.Designer.cs',
#  '../data/AMC/Measure/GeomDrawRegionController.cs',
#  '../data/AMC/Measure/RefreshForm.cs',
#  '../data/AMC/Measure/Controller/BScanCtrller.cs',
#  '../data/AMC/Measure/Controller/CScanOfflineCtrller.cs',
#  '../data/AMC/Measure/Controller/CscanOnlineCtrller.cs',
#  '../data/AMC/Measure/DrawObjects/DrawAScanLine.cs',
#  '../data/AMC/Measure/DrawObjects/DrawCross.cs',
#  '../data/AMC/Measure/DrawObjects/DrawGate.cs',
#  '../data/AMC/Measure/DrawObjects/DrawHorLine.cs',
#  '../data/AMC/Measure/DrawObjects/DrawVerLine.cs',
#  '../data/AMC/Measure/DrawObjects/DrawVerLineCM.cs',
#  '../data/AMC/Measure/DrawObjects/IDraw.cs',
#  '../data/AMC/Measure/DrawObjects/TransMatrix.cs',
#  '../data/AMC/Measure/DrawObjects/Bitmaps/CBitmapAScan.cs',
#  '../data/AMC/Measure/DrawObjects/Bitmaps/CBitmapEightBits.cs',
#  '../data/AMC/Measure/DrawObjects/Bitmaps/RefSize.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/FineSweepRectangle.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/MeasureBase.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/MeasureCircle.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/MeasureLine.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/MeasureMultLine.cs',
#  '../data/AMC/Measure/DrawObjects/Measure/MeasureRectangle.cs',
#  '../data/AMC/Measure/DrawObjects/Tools/ITool.cs',
#  '../data/AMC/Measure/DrawObjects/Tools/ToolPointer.cs',
#  '../data/AMC/Measure/DrawObjects/Xml/IXmlObject.cs',
#  '../data/AMC/Measure/DrawObjects/Xml/XRemarkGroup.cs',
#  '../data/AMC/Measure/DrawObjects/Xml/XRemarkGroups.cs',
#  '../data/AMC/Measure/DrawObjects/Xml/XRemarks.cs',
#  '../data/AMC/Measure/DrawObjects/Xml/XSyncGate.cs',
#  '../data/AMC/Measure/Managers/ActionManager.cs',
#  '../data/AMC/Measure/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Measure/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Measure/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Measure/Properties/AssemblyInfo.cs',
#  '../data/AMC/PLCLib/EnumExtensions.cs',
#  '../data/AMC/PLCLib/PlcTool.cs',
#  '../data/AMC/PLCLib/PlcTool.DataSet.cs',
#  '../data/AMC/PLCLib/PlcTool.ReadAndWrite.cs',
#  '../data/AMC/PLCLib/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/PLCLib/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/PLCLib/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/PLCLib/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/PLCLib/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/PLCLib/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/PLCLib/Properties/AssemblyInfo.cs',
#  '../data/AMC/Utils/CommonUtil.cs',
#  '../data/AMC/Utils/ComplexNumber.cs',
#  '../data/AMC/Utils/ConvertType.cs',
#  '../data/AMC/Utils/DataUtils.cs',
#  '../data/AMC/Utils/DMUtils.cs',
#  '../data/AMC/Utils/encrypt.cs',
#  '../data/AMC/Utils/ExCircleQueue.cs',
#  '../data/AMC/Utils/ExecAction.cs',
#  '../data/AMC/Utils/FftAlgorithm.cs',
#  '../data/AMC/Utils/Functions.cs',
#  '../data/AMC/Utils/GZip.cs',
#  '../data/AMC/Utils/JsonHelper.cs',
#  '../data/AMC/Utils/Log.cs',
#  '../data/AMC/Utils/LogAsync.cs',
#  '../data/AMC/Utils/SystemInfo.cs',
#  '../data/AMC/Utils/XmlHelper.cs',
#  '../data/AMC/Utils/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils/obj/x64/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils/obj/x64/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils/obj/x64/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/Utils/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/Utils/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/Utils/Properties/AssemblyInfo.cs',
#  '../data/AMC/XmlConfigs/AxisInfo.cs',
#  '../data/AMC/XmlConfigs/AxisSetting.cs',
#  '../data/AMC/XmlConfigs/Class1.cs',
#  '../data/AMC/XmlConfigs/ConfigItem.cs',
#  '../data/AMC/XmlConfigs/CorrectWave.cs',
#  '../data/AMC/XmlConfigs/DPR.cs',
#  '../data/AMC/XmlConfigs/DPRConfig.cs',
#  '../data/AMC/XmlConfigs/DPRInfo.cs',
#  '../data/AMC/XmlConfigs/Glconfiguration.cs',
#  '../data/AMC/XmlConfigs/IndexAxis.cs',
#  '../data/AMC/XmlConfigs/Laycontrol.cs',
#  '../data/AMC/XmlConfigs/MotionLayout.cs',
#  '../data/AMC/XmlConfigs/ScanAxis.cs',
#  '../data/AMC/XmlConfigs/ScanSetting.cs',
#  '../data/AMC/XmlConfigs/WaveInfo.cs',
#  '../data/AMC/XmlConfigs/WaveSetting.cs',
#  '../data/AMC/XmlConfigs/obj/Debug/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs/obj/Debug/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs/obj/Debug/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs/obj/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs/obj/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs/obj/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs/obj/x64/Release/TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92.cs',
#  '../data/AMC/XmlConfigs/obj/x64/Release/TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1.cs',
#  '../data/AMC/XmlConfigs/obj/x64/Release/TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3.cs',
#  '../data/AMC/XmlConfigs/Properties/AssemblyInfo.cs']

# %%
ref_dict['../data/AMC/AMC/Form1.cs']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 ref_dict['../data/AMC/AMC/Form1.cs']
#
# KeyError: '../data/AMC/AMC/Form1.cs'

# %%
ref_dict.keys()
# Out:
# dict_keys(['AlgorithmLib.CScanPicFunction', 'AlgorithmLib.CScanPicFunctionGPU - 副本 (2)', 'AlgorithmLib.CScanPicFunctionGPU - 副本', 'AlgorithmLib.CScanPicFunctionGPU', 'AlgorithmLib.UltrasonicalPeakDll', 'AlgorithmLib.obj.Debug.TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92', 'AlgorithmLib.obj.Debug.TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1', 'AlgorithmLib.obj.Debug.TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3', 'AlgorithmLib.obj.Release.TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92', 'AlgorithmLib.obj.Release.TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1', 'AlgorithmLib.obj.Release.TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3', 'AlgorithmLib.obj.x64.Debug.TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92', 'AlgorithmLib.obj.x64.Debug.TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1', 'AlgorithmLib.obj.x64.Debug.TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3', 'AlgorithmLib.obj.x64.Release.TemporaryGeneratedFile_036C0B5B-1481-4323-8D20-8F5ADCB23D92', 'AlgorithmLib.obj.x64.Release.TemporaryGeneratedFile_5937a670-0e60-4077-877b-f7221da3dda1', 'AlgorithmLib.obj.x64.Release.TemporaryGeneratedFile_E7A71F73-0F8D-4B9B-B56E-8E70B10BC5D3', 'AlgorithmLib.Properties.AssemblyInfo', 'AlgorithmLib.Properties.Resources.Designer', 'AlgorithmLib.Properties.Settings.Designer', 'AMC.About', 'AMC.About.Designer', 'AMC.AreaEdit', 'AMC.AreaEdit.designer', 'AMC.AsResult', 'AMC.AsResult.Designer', 'AMC.BScanImageForm', 'AMC.BScanImageForm.Designer', 'AMC.CheckUserFrm', 'AMC.CheckUserFrm.Designer', 'AMC.CScanPic', 'AMC.CScanPic.Designer', 'AMC.ExternalIterface', 'AMC.FftForm', 'AMC.FftForm.Designer', 'AMC.Form1', 'AMC.Form1.Designer', 'AMC.Form1_AutoScan.Designer', 'AMC.Form1_DataManager.Designer', 'AMC.Form1_DataProcess.Designer', 'AMC.Form1_Gail.Designer', 'AMC.Form1_Task.Designer', 'AMC.Form1_Test.Designer', 'AMC.FreqPara', 'AMC.FreqPara.Designer', 'AMC.frmMark', 'AMC.frmMark.Designer', 'AMC.frmRemarkList', 'AMC.frmRemarkList.Designer', 'AMC.JSRControlForm', 'AMC.JSRControlForm.Designer', 'AMC.LayoutControl1', 'AMC.LayoutControl1.designer', 'AMC.LayoutSet', 'AMC.LayoutSet.designer', 'AMC.LoadingForm', 'AMC.LoadingForm.Designer', 'AMC.LoadingHelper', 'AMC.LoginForm', 'AMC.LoginForm.designer', 'AMC.MeasurePareFrm', 'AMC.MeasurePareFrm.Designer', 'AMC.MeasureVzForm', 'AMC.MeasureVzForm.Designer', 'AMC.MyAscan', 'AMC.MyAscan.Designer', 'AMC.MyAscanOffline', 'AMC.MyAscanOffline.Designer', 'AMC.OfflineCScanPic', 'AMC.OfflineCScanPic.Designer', 'AMC.OutlookSettingForm', 'AMC.OutlookSettingForm.Designer', 'AMC.Program', 'AMC.Resource1.Designer', 'AMC.SecondFrm', 'AMC.SecondFrm.Designer', 'AMC.SelectImgStyle', 'AMC.SelectImgStyle.Designer', 'AMC.SelfDefineImgSizeFrm', 'AMC.SelfDefineImgSizeFrm.Designer', 'AMC.SuspendForm', 'AMC.SuspendForm.Designer', 'AMC.UMSpdf', 'AMC.UMSpdf.Designer', 'AMC.UserControlRegion', 'AMC.UserControlRegion.designer', 'AMC.WaitForm1', 'AMC.WaitForm1.designer', 'AMC.WaveOffsetForm', 'AMC.WaveOffsetForm.Designer', 'AMC.WaveSetting', 'AMC.WorkPartSet', 'AMC.WorkPartSet.designer', 'AMC.WorkpieceStatus', 'AMC.WorkpieceStatus.Designer', 'AMC.AutoScan.AbstractAutoScanTask', 'AMC.AutoScan.AutoScanLog', 'AMC.AutoScan.AutoScanParallelTask', 'AMC.AutoScan.AutoScanSerialTask', 'AMC.AutoScan.PlcCommand', 'AMC.AutoScan.PointXYZ', 'AMC.AutoScan.RobotStatus', 'AMC.AutoScan.UI_MonitorIO', 'AMC.AutoScan.UI_MonitorIO.designer', 'AMC.AutoScan.WorkPieceAuto', 'AMC.DM.AdaptFont', 'AMC.DM.AuthorityControl', 'AMC.DM.EnumClass', 'AMC.DM.Form_Acc', 'AMC.DM.Form_Acc.designer', 'AMC.DM.Form_Acc_Add', 'AMC.DM.Form_Acc_Add.designer', 'AMC.DM.Form_Acc_Check', 'AMC.DM.Form_Acc_Check.designer', 'AMC.DM.Form_Axises', 'AMC.DM.Form_Axises.designer', 'AMC.DM.Form_Axises_Add', 'AMC.DM.Form_Axises_Add.designer', 'AMC.DM.Form_Cells_Edit', 'AMC.DM.Form_Cells_Edit.designer', 'AMC.DM.Form_Couplants', 'AMC.DM.Form_Couplants.Designer', 'AMC.DM.Form_Couplan ...

# %% [markdown]
# ## 4. 保存最终结果

# %%
json.dump(ref_dict, open('../data/processed/amc-by-tree-sitter.json','w'))
